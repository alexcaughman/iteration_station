# %%
#import dependencies
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
#reading in weather data from csv
Csvpath = "weather_data2018-19_csv.csv"
weather_data = pd.read_csv(Csvpath)
weather_data['Date time']= pd.to_datetime(weather_data['Date time']) 
weather_data['Date'] = weather_data['Date time'].dt.strftime('%m/%d/%Y')
weather_data = weather_data[['Location', 'Address', 'Country', 'Date', 'Maximum Temperature',
       'Minimum Temperature', 'Temperature', 'Wind Chill', 'Heat Index',
       'Precipitation', 'Snow Depth', 'Wind Speed', 'Wind Gust', 'Cloud Cover',
       'Relative Humidity', 'Conditions']]
weather_data
# Out:
#       Location  Address Country        Date  Maximum Temperature  \
# 0          NaN    30308     USA  01/01/2019                 64.9
# 1          NaN    30308     USA  01/02/2019                 56.8
# 2          NaN    30308     USA  01/03/2019                 54.4
# 3          NaN    30308     USA  01/04/2019                 64.6
# 4          NaN    30308     USA  01/05/2019                 57.5
# ...        ...      ...     ...         ...                  ...
# 7295       NaN    30308     USA  12/27/2018                 52.9
# 7296       NaN    30308     USA  12/28/2018                 62.0
# 7297       NaN    30308     USA  12/29/2018                 59.5
# 7298       NaN    30308     USA  12/30/2018                 54.3
# 7299       NaN    30308     USA  12/31/2018                 69.4
#
#       Minimum Temperature  Temperature  Wind Chill  Heat Index  Precipitation  \
# 0                    56.1         61.2         NaN         NaN            0.2
# ...

# %%
#reading in traffic data from csv Traffic csvs
Csvpath_30308 = "30308_Traffic_data_final.csv"
Csvpath_30309 = "30309_Traffic_data_final.csv"
Csvpath_30312 = "30312_Traffic_data_final.csv"
Csvpath_30315 = "30315_Traffic_data_final.csv"
Csvpath_30318 = "30318_Traffic_data_final.csv"
Csvpath_30324 = "30324_Traffic_data_final.csv"
Csvpath_30331 = "30331_Traffic_data_final.csv"
Csvpath_30339 = "30339_Traffic_data_final.csv"
Csvpath_30340 = "30340_Traffic_data_final.csv"
Csvpath_30342 = "30342_Traffic_data_final.csv"


traffic_data_30312 = pd.read_csv(Csvpath_30312)
traffic_data_30315 = pd.read_csv(Csvpath_30315)
traffic_data_30309 = pd.read_csv(Csvpath_30309)
traffic_data_30339 = pd.read_csv(Csvpath_30339)
traffic_data_30331 = pd.read_csv(Csvpath_30331)
traffic_data_30340 = pd.read_csv(Csvpath_30340)
traffic_data_30324 = pd.read_csv(Csvpath_30324)
traffic_data_30308 = pd.read_csv(Csvpath_30308)
traffic_data_30318 = pd.read_csv(Csvpath_30318)
traffic_data_30342 = pd.read_csv(Csvpath_30342)
traffic_data_30339
# Out:
#            Date  Severity_1  Severity_2  Severity_3  Severity_4  \
# 0    01/01/2018           0           0           0           0
# 1    01/02/2018           0           0           3           0
# 2    01/03/2018           0           0           0           0
# 3    01/04/2018           0           0           0           0
# 4    01/05/2018           0           0           0           0
# ..          ...         ...         ...         ...         ...
# 725  12/27/2019           0           0           0           0
# 726  12/28/2019           0           0           2           0
# 727  12/29/2019           0           1           2           0
# 728  12/30/2019           0           0           0           0
# 729  12/31/2019           0           0           0           0
#
#      Residential_ct  Interstate_ct  Accident_ct  Zipcode
# 0                 0              0            0    30339
# 1                 0              3            3    30339
# ...

# %%
#creating separate weather dataframes for each zipcode
weather_data_30312 = weather_data.loc[weather_data["Address"]==30312,:]
weather_data_30315 = weather_data.loc[weather_data["Address"]==30315,:]
weather_data_30309 = weather_data.loc[weather_data["Address"]==30309,:]
weather_data_30339 = weather_data.loc[weather_data["Address"]==30339,:]
weather_data_30331 = weather_data.loc[weather_data["Address"]==30331,:]
weather_data_30340 = weather_data.loc[weather_data["Address"]==30340,:]
weather_data_30324 = weather_data.loc[weather_data["Address"]==30324,:]
weather_data_30308 = weather_data.loc[weather_data["Address"]==30308,:]
weather_data_30318 = weather_data.loc[weather_data["Address"]==30318,:]
weather_data_30342 = weather_data.loc[weather_data["Address"]==30342,:]
weather_data_30315
# Out:
#       Location  Address Country        Date  Maximum Temperature  \
# 1095       NaN    30315     USA  01/01/2019                 65.4
# 1096       NaN    30315     USA  01/02/2019                 57.3
# 1097       NaN    30315     USA  01/03/2019                 54.6
# 1098       NaN    30315     USA  01/04/2019                 65.2
# 1099       NaN    30315     USA  01/05/2019                 58.3
# ...        ...      ...     ...         ...                  ...
# 5013       NaN    30315     USA  12/27/2018                 53.5
# 5014       NaN    30315     USA  12/28/2018                 62.2
# 5015       NaN    30315     USA  12/29/2018                 60.3
# 5016       NaN    30315     USA  12/30/2018                 54.8
# 5017       NaN    30315     USA  12/31/2018                 69.8
#
#       Minimum Temperature  Temperature  Wind Chill  Heat Index  Precipitation  \
# 1095                 56.9         62.0         NaN         NaN            0.2
# ...

# %%
#30312 traffic and weather merge
weather_traffic_30312 = pd.merge(weather_data_30312, traffic_data_30312, on = "Date", how = "left")
weather_traffic_30312["Accident_ct"].sum()
# Out:
# 1752

# %%
#30315 traffic and weather merge
weather_traffic_30315 = pd.merge(weather_data_30315, traffic_data_30315, on = "Date", how = "left")
#30309  traffic and weather merge
weather_traffic_30309 = pd.merge(weather_data_30309, traffic_data_30309, on = "Date", how = "left")
#30339 traffic and weather merge
weather_traffic_30339 = pd.merge(weather_data_30339, traffic_data_30339, on = "Date", how = "left")
#30331 traffic and weather merge
weather_traffic_30331 = pd.merge(weather_data_30331, traffic_data_30331, on = "Date", how = "left")
#30340 traffic and weather merge
weather_traffic_30340 = pd.merge(weather_data_30340, traffic_data_30340, on = "Date", how = "left")
#30324 traffic and weather merge
weather_traffic_30324 = pd.merge(weather_data_30324, traffic_data_30324, on = "Date", how = "left")
#30308 traffic and weather merge
weather_traffic_30308 = pd.merge(weather_data_30308, traffic_data_30308, on = "Date", how = "left")
#30318 traffic and weather merge
weather_traffic_30318 = pd.merge(weather_data_30318, traffic_data_30318, on = "Date", how = "left")
#30342 traffic and weather merge
weather_traffic_30342 = pd.merge(weather_data_30342, traffic_data_30342, on = "Date", how = "left")

# %%
test = weather_traffic_30318["Severity_1"].sum()+weather_traffic_30318["Severity_2"].sum()+weather_traffic_30318["Severity_3"].sum()+weather_traffic_30318["Severity_4"].sum()
test
# Out:
# 819

# %%
weather_traffic_30312.to_csv('30312_weather_traffic_FINAL.csv',index = True, header = True)
weather_traffic_30339.to_csv('30339_weather_traffic_FINAL.csv',index = True, header = True)
weather_traffic_30331.to_csv('30331_weather_traffic_FINAL.csv',index = True, header = True)
weather_traffic_30315.to_csv('30315_weather_traffic_FINAL.csv',index = True, header = True)
weather_traffic_30309.to_csv('30309_weather_traffic_FINAL.csv',index = True, header = True)
weather_traffic_30340.to_csv('30340_weather_traffic_FINAL.csv',index = True, header = True)
weather_traffic_30308.to_csv('30308_weather_traffic_FINAL.csv',index = True, header = True)
weather_traffic_30324.to_csv('30324_weather_traffic_FINAL.csv',index = True, header = True)
weather_traffic_30342.to_csv('30342_weather_traffic_FINAL.csv',index = True, header = True)
weather_traffic_30318.to_csv('30318_weather_traffic_FINAL.csv',index = True, header = True)
