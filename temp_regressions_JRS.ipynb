# %% [markdown]
# #import csv
# import pandas as pd
# import matplotlib.pyplot as plt
# import scipy.stats as st
# import numpy as np
# from scipy.stats import linregress

# %%
#dependencies
import csv
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# %%
#read in zip csv's
zip30312 = "Weather_Traffic_Resources/30312_weather_traffic_FINAL.csv"
zip30339 = "Weather_Traffic_Resources/30339_weather_traffic_FINAL.csv"
zip30331 = "Weather_Traffic_Resources/30331_weather_traffic_FINAL.csv"
zip30315 = "Weather_Traffic_Resources/30315_weather_traffic_FINAL.csv"
zip30309 = "Weather_Traffic_Resources/30309_weather_traffic_FINAL.csv"
zip30340 = "Weather_Traffic_Resources/30340_weather_traffic_FINAL.csv"
zip30308 = "Weather_Traffic_Resources/30308_weather_traffic_FINAL.csv"
zip30324 = "Weather_Traffic_Resources/30324_weather_traffic_FINAL.csv"
zip30342 = "Weather_Traffic_Resources/30342_weather_traffic_FINAL.csv"
zip30318 = "Weather_Traffic_Resources/30318_weather_traffic_FINAL.csv"

zip30312_df = pd.read_csv(zip30312)
zip30339_df = pd.read_csv(zip30339)
zip30331_df = pd.read_csv(zip30331)
zip30315_df = pd.read_csv(zip30315)
zip30309_df = pd.read_csv(zip30309)
zip30340_df = pd.read_csv(zip30340)
zip30308_df = pd.read_csv(zip30308)
zip30324_df = pd.read_csv(zip30324)
zip30342_df = pd.read_csv(zip30342)
zip30318_df = pd.read_csv(zip30318)

zip30312_df.head()
# Out:
#    Unnamed: 0  Location  Address Country        Date  Maximum Temperature  \
# 0           0       NaN    30312     USA  01/01/2019                 65.1
# 1           1       NaN    30312     USA  01/02/2019                 57.0
# 2           2       NaN    30312     USA  01/03/2019                 54.3
# 3           3       NaN    30312     USA  01/04/2019                 64.8
# 4           4       NaN    30312     USA  01/05/2019                 57.8
#
#    Minimum Temperature  Temperature  Wind Chill  Heat Index  ...  \
# 0                 56.4         61.5         NaN         NaN  ...
# 1                 49.0         52.4        46.3         NaN  ...
# 2                 50.1         52.5         NaN         NaN  ...
# 3                 45.1         54.5        40.1         NaN  ...
# 4                 43.7         48.8        36.4         NaN  ...
#
#    Relative Humidity              Conditions  Severity_1  Severity_2  \
# ...

# %%
#accidents with temperature over 80
HiTemp30312 = zip30312_df.loc[zip30312_df['Maximum Temperature'] > 80,['Maximum Temperature','Accident_ct']]
HiTemp30339 = zip30339_df.loc[zip30339_df['Maximum Temperature'] > 80,['Maximum Temperature','Accident_ct']]
HiTemp30331 = zip30331_df.loc[zip30331_df['Maximum Temperature'] > 80,['Maximum Temperature','Accident_ct']]
HiTemp30315 = zip30315_df.loc[zip30315_df['Maximum Temperature'] > 80,['Maximum Temperature','Accident_ct']]
HiTemp30309 = zip30309_df.loc[zip30309_df['Maximum Temperature'] > 80,['Maximum Temperature','Accident_ct']]
HiTemp30340 = zip30340_df.loc[zip30340_df['Maximum Temperature'] > 80,['Maximum Temperature','Accident_ct']]
HiTemp30308 = zip30308_df.loc[zip30308_df['Maximum Temperature'] > 80,['Maximum Temperature','Accident_ct']]
HiTemp30324 = zip30324_df.loc[zip30324_df['Maximum Temperature'] > 80,['Maximum Temperature','Accident_ct']]
HiTemp30342 = zip30342_df.loc[zip30342_df['Maximum Temperature'] > 80,['Maximum Temperature','Accident_ct']]
HiTemp30318 = zip30318_df.loc[zip30318_df['Maximum Temperature'] > 80,['Maximum Temperature','Accident_ct']]
HiTemp30312.head()
# Out:
#      Maximum Temperature  Accident_ct
# 99                  81.5            3
# 100                 81.1            1
# 102                 81.3            5
# 106                 80.1            0
# 111                 80.4            2

# %%
# accidents with temperature below 80 
LoTemp30312 = zip30312_df.loc[zip30312_df['Maximum Temperature'] < 80,['Maximum Temperature','Accident_ct']]
LoTemp30339 = zip30339_df.loc[zip30339_df['Maximum Temperature'] < 80,['Maximum Temperature','Accident_ct']]
LoTemp30331 = zip30331_df.loc[zip30331_df['Maximum Temperature'] < 80,['Maximum Temperature','Accident_ct']]
LoTemp30315 = zip30315_df.loc[zip30315_df['Maximum Temperature'] < 80,['Maximum Temperature','Accident_ct']]
LoTemp30309 = zip30309_df.loc[zip30309_df['Maximum Temperature'] < 80,['Maximum Temperature','Accident_ct']]
LoTemp30340 = zip30340_df.loc[zip30340_df['Maximum Temperature'] < 80,['Maximum Temperature','Accident_ct']]
LoTemp30308 = zip30308_df.loc[zip30308_df['Maximum Temperature'] < 80,['Maximum Temperature','Accident_ct']]
LoTemp30324 = zip30324_df.loc[zip30324_df['Maximum Temperature'] < 80,['Maximum Temperature','Accident_ct']]
LoTemp30342 = zip30342_df.loc[zip30342_df['Maximum Temperature'] < 80,['Maximum Temperature','Accident_ct']]
LoTemp30318 = zip30318_df.loc[zip30318_df['Maximum Temperature'] < 80,['Maximum Temperature','Accident_ct']]
LoTemp30312.head()
# Out:
#    Maximum Temperature  Accident_ct
# 0                 65.1            2
# 1                 57.0            1
# 2                 54.3            4
# 3                 64.8            4
# 4                 57.8            2

# %%
#high temp 30312

(slope, intercept, rvalue, pvalue, stderr) = linregress(HiTemp30312['Maximum Temperature'], HiTemp30312['Accident_ct'])
regress_values = slope * HiTemp30312['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(HiTemp30312['Maximum Temperature'], HiTemp30312['Accident_ct'])
plt.plot(HiTemp30312['Maximum Temperature'], regress_values, color = 'red',label = "High Temp fitted line")
plt.legend()
plt.annotate(line_eq,(80,15.2),fontsize=10,color="red")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30312")
corr=round(st.pearsonr(HiTemp30312['Maximum Temperature'], HiTemp30312['Accident_ct'])[0],2)*100
print(f"The correlation between High Temperature and accidents for zip code 30312 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)



#low temp 30312

(slope, intercept, rvalue, pvalue, stderr) = linregress(LoTemp30312['Maximum Temperature'], LoTemp30312['Accident_ct'])
regress_values = slope * LoTemp30312['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(LoTemp30312['Maximum Temperature'], LoTemp30312['Accident_ct'])
plt.plot(LoTemp30312['Maximum Temperature'], regress_values, color = "green",label = "Low Temp fitted line")
plt.legend()
plt.annotate(line_eq,(40,12.5),fontsize=10,color="green")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30312")
corr=round(st.pearsonr(LoTemp30312['Maximum Temperature'], LoTemp30312['Accident_ct'])[0],2)*100
print(f"The correlation between Low Temperature and accidents for zip code 30312 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between High Temperature and accidents for zip code 30312 is -12.0%
# slope: -0.076096  intercept: 9.173555
# R-Squared: 0.014795
# The correlation between Low Temperature and accidents for zip code 30312 is -8.0%
# slope: -0.017624  intercept: 3.913133
# R-Squared: 0.006484

# %%
#high temp 30339

(slope, intercept, rvalue, pvalue, stderr) = linregress(HiTemp30339['Maximum Temperature'], HiTemp30339['Accident_ct'])
regress_values = slope * HiTemp30339['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(HiTemp30339['Maximum Temperature'], HiTemp30339['Accident_ct'])
plt.plot(HiTemp30339['Maximum Temperature'], regress_values, color = 'red',label = "High Temp fitted line")
plt.legend()
plt.annotate(line_eq,(80,15.2),fontsize=10,color="red")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30339")
corr=round(st.pearsonr(HiTemp30339['Maximum Temperature'], HiTemp30339['Accident_ct'])[0],2)*100
print(f"The correlation between High Temperature and accidents for zip code 30339 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)

#low temp 30339

(slope, intercept, rvalue, pvalue, stderr) = linregress(LoTemp30339['Maximum Temperature'], LoTemp30339['Accident_ct'])
regress_values = slope * LoTemp30339['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(LoTemp30339['Maximum Temperature'], LoTemp30339['Accident_ct'])
plt.plot(LoTemp30339['Maximum Temperature'], regress_values, color = "green",label = "Low Temp fitted line")
plt.legend()
plt.annotate(line_eq,(40,12.5),fontsize=10,color="green")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30339")
corr=round(st.pearsonr(LoTemp30339['Maximum Temperature'], LoTemp30339['Accident_ct'])[0],2)*100
print(f"The correlation between Low Temperature and accidents for zip code 30339 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between High Temperature and accidents for zip code 30339 is -6.0%
# slope: -0.034218  intercept: 4.588876
# R-Squared: 0.003529
# The correlation between Low Temperature and accidents for zip code 30339 is 4.0%
# slope: 0.006489  intercept: 1.132401
# R-Squared: 0.001629

# %%
#high temp 30331

(slope, intercept, rvalue, pvalue, stderr) = linregress(HiTemp30331['Maximum Temperature'], HiTemp30331['Accident_ct'])
regress_values = slope * HiTemp30331['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(HiTemp30331['Maximum Temperature'], HiTemp30331['Accident_ct'])
plt.plot(HiTemp30331['Maximum Temperature'], regress_values, color = 'red',label = "High Temp fitted line")
plt.legend()
plt.annotate(line_eq,(65,8.5),fontsize=10,color="red")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30331")
corr=round(st.pearsonr(HiTemp30331['Maximum Temperature'], HiTemp30331['Accident_ct'])[0],2)*100
print(f"The correlation between High Temperature and accidents for zip code 30331 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)

#low temp 30331

(slope, intercept, rvalue, pvalue, stderr) = linregress(LoTemp30331['Maximum Temperature'], LoTemp30331['Accident_ct'])
regress_values = slope * LoTemp30331['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(LoTemp30331['Maximum Temperature'], LoTemp30331['Accident_ct'])
plt.plot(LoTemp30331['Maximum Temperature'], regress_values, color = "green",label = "Low Temp fitted line")
plt.legend()
plt.annotate(line_eq,(30,8),fontsize=10,color="green")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30331")
corr=round(st.pearsonr(LoTemp30331['Maximum Temperature'], LoTemp30331['Accident_ct'])[0],2)*100
print(f"The correlation between Low Temperature and accidents for zip code 30331 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between High Temperature and accidents for zip code 30331 is -9.0%
# slope: -0.036047  intercept: 4.778922
# R-Squared: 0.007663
# The correlation between Low Temperature and accidents for zip code 30331 is -2.0%
# slope: -0.002798  intercept: 1.913786
# R-Squared: 0.000335

# %%
#high temp 30315

(slope, intercept, rvalue, pvalue, stderr) = linregress(HiTemp30315['Maximum Temperature'], HiTemp30315['Accident_ct'])
regress_values = slope * HiTemp30315['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(HiTemp30315['Maximum Temperature'], HiTemp30315['Accident_ct'])
plt.plot(HiTemp30315['Maximum Temperature'], regress_values, color = 'red',label = "High Temp fitted line")
plt.legend()
plt.annotate(line_eq,(65,10),fontsize=10,color="red")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30315")
corr=round(st.pearsonr(HiTemp30315['Maximum Temperature'], HiTemp30315['Accident_ct'])[0],2)*100
print(f"The correlation between High Temperature and accidents for zip code 30315 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)

#low temp 30315

(slope, intercept, rvalue, pvalue, stderr) = linregress(LoTemp30315['Maximum Temperature'], LoTemp30315['Accident_ct'])
regress_values = slope * LoTemp30315['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(LoTemp30315['Maximum Temperature'], LoTemp30315['Accident_ct'])
plt.plot(LoTemp30315['Maximum Temperature'], regress_values, color = "green",label = "Low Temp fitted line")
plt.legend()
plt.annotate(line_eq,(30,10),fontsize=10,color="green")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30315")
corr=round(st.pearsonr(LoTemp30315['Maximum Temperature'], LoTemp30315['Accident_ct'])[0],2)*100
print(f"The correlation between Low Temperature and accidents for zip code 30315 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between High Temperature and accidents for zip code 30315 is -13.0%
# slope: -0.061650  intercept: 6.995591
# R-Squared: 0.017265
# The correlation between Low Temperature and accidents for zip code 30315 is -2.0%
# slope: -0.004770  intercept: 2.361715
# R-Squared: 0.000540

# %%
#high temp 30309

(slope, intercept, rvalue, pvalue, stderr) = linregress(HiTemp30309['Maximum Temperature'], HiTemp30309['Accident_ct'])
regress_values = slope * HiTemp30309['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(HiTemp30309['Maximum Temperature'], HiTemp30309['Accident_ct'])
plt.plot(HiTemp30309['Maximum Temperature'], regress_values, color = 'red',label = "High Temp fitted line")
plt.legend()
plt.annotate(line_eq,(75,11),fontsize=10,color="red")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30309")
corr=round(st.pearsonr(HiTemp30309['Maximum Temperature'], HiTemp30309['Accident_ct'])[0],2)*100
print(f"The correlation between High Temperature and accidents for zip code 30309 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)

#low temp 30309

(slope, intercept, rvalue, pvalue, stderr) = linregress(LoTemp30309['Maximum Temperature'], LoTemp30309['Accident_ct'])
regress_values = slope * LoTemp30309['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(LoTemp30309['Maximum Temperature'], LoTemp30309['Accident_ct'])
plt.plot(LoTemp30309['Maximum Temperature'], regress_values, color = "green",label = "Low Temp fitted line")
plt.legend()
plt.annotate(line_eq,(30,8),fontsize=10,color="green")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30309")
corr=round(st.pearsonr(LoTemp30309['Maximum Temperature'], LoTemp30309['Accident_ct'])[0],2)*100
print(f"The correlation between Low Temperature and accidents for zip code 30309 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between High Temperature and accidents for zip code 30309 is -17.0%
# slope: -0.088968  intercept: 9.892717
# R-Squared: 0.028833
# The correlation between Low Temperature and accidents for zip code 30309 is 0.0%
# slope: 0.000099  intercept: 1.934494
# R-Squared: 0.000000

# %%
#high temp 30340

(slope, intercept, rvalue, pvalue, stderr) = linregress(HiTemp30340['Maximum Temperature'], HiTemp30340['Accident_ct'])
regress_values = slope * HiTemp30340['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(HiTemp30340['Maximum Temperature'], HiTemp30340['Accident_ct'])
plt.plot(HiTemp30340['Maximum Temperature'], regress_values, color = 'red',label = "High Temp fitted line")
plt.legend()
plt.annotate(line_eq,(70,15.2),fontsize=10,color="red")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30340")
corr=round(st.pearsonr(HiTemp30340['Maximum Temperature'], HiTemp30340['Accident_ct'])[0],2)*100
print(f"The correlation between High Temperature and accidents for zip code 30340 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)

#low temp 30340

(slope, intercept, rvalue, pvalue, stderr) = linregress(LoTemp30340['Maximum Temperature'], LoTemp30340['Accident_ct'])
regress_values = slope * LoTemp30340['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(LoTemp30340['Maximum Temperature'], LoTemp30340['Accident_ct'])
plt.plot(LoTemp30340['Maximum Temperature'], regress_values, color = "green",label = "Low Temp fitted line")
plt.legend()
plt.annotate(line_eq,(27,8),fontsize=10,color="green")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30340")
corr=round(st.pearsonr(LoTemp30340['Maximum Temperature'], LoTemp30340['Accident_ct'])[0],2)*100
print(f"The correlation between Low Temperature and accidents for zip code 30340 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between High Temperature and accidents for zip code 30340 is -5.0%
# slope: -0.029584  intercept: 4.068171
# R-Squared: 0.002583
# The correlation between Low Temperature and accidents for zip code 30340 is -1.0%
# slope: -0.001678  intercept: 1.621868
# R-Squared: 0.000087

# %%
#high temp 30308

(slope, intercept, rvalue, pvalue, stderr) = linregress(HiTemp30308['Maximum Temperature'], HiTemp30308['Accident_ct'])
regress_values = slope * HiTemp30308['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(HiTemp30308['Maximum Temperature'], HiTemp30308['Accident_ct'])
plt.plot(HiTemp30308['Maximum Temperature'], regress_values, color = 'red',label = "High Temp fitted line")
plt.legend()
plt.annotate(line_eq,(75,7.4),fontsize=10,color="red")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30308")
corr=round(st.pearsonr(HiTemp30308['Maximum Temperature'], HiTemp30308['Accident_ct'])[0],2)*100
print(f"The correlation between High Temperature and accidents for zip code 30308 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)

#low temp 30308

(slope, intercept, rvalue, pvalue, stderr) = linregress(LoTemp30308['Maximum Temperature'], LoTemp30308['Accident_ct'])
regress_values = slope * LoTemp30308['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(LoTemp30308['Maximum Temperature'], LoTemp30308['Accident_ct'])
plt.plot(LoTemp30308['Maximum Temperature'], regress_values, color = "green",label = "Low Temp fitted line")
plt.legend()
plt.annotate(line_eq,(28,4.4),fontsize=10,color="green")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30308")
corr=round(st.pearsonr(LoTemp30308['Maximum Temperature'], LoTemp30308['Accident_ct'])[0],2)*100
print(f"The correlation between Low Temperature and accidents for zip code 30308 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between High Temperature and accidents for zip code 30308 is -10.0%
# slope: -0.048666  intercept: 6.014854
# R-Squared: 0.010906
# The correlation between Low Temperature and accidents for zip code 30308 is -3.0%
# slope: -0.004535  intercept: 1.978665
# R-Squared: 0.000837

# %%
#high temp 30324

(slope, intercept, rvalue, pvalue, stderr) = linregress(HiTemp30324['Maximum Temperature'], HiTemp30324['Accident_ct'])
regress_values = slope * HiTemp30324['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(HiTemp30324['Maximum Temperature'], HiTemp30324['Accident_ct'])
plt.plot(HiTemp30324['Maximum Temperature'], regress_values, color = 'red',label = "High Temp fitted line")
plt.legend()
plt.annotate(line_eq,(75,10),fontsize=10,color="red")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30324")
corr=round(st.pearsonr(HiTemp30324['Maximum Temperature'], HiTemp30324['Accident_ct'])[0],2)*100
print(f"The correlation between High Temperature and accidents for zip code 30324 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)

#low temp 30324

(slope, intercept, rvalue, pvalue, stderr) = linregress(LoTemp30324['Maximum Temperature'], LoTemp30324['Accident_ct'])
regress_values = slope * LoTemp30324['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(LoTemp30324['Maximum Temperature'], LoTemp30324['Accident_ct'])
plt.plot(LoTemp30324['Maximum Temperature'], regress_values, color = "green",label = "Low Temp fitted line")
plt.legend()
plt.annotate(line_eq,(28,6.5),fontsize=10,color="green")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30324")
corr=round(st.pearsonr(LoTemp30324['Maximum Temperature'], LoTemp30324['Accident_ct'])[0],2)*100
print(f"The correlation between Low Temperature and accidents for zip code 30324 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
plt.savefig("Images/Temp_30324")
# Out:
# The correlation between High Temperature and accidents for zip code 30324 is -16.0%
# slope: -0.080343  intercept: 8.587024
# R-Squared: 0.026933
# The correlation between Low Temperature and accidents for zip code 30324 is -5.0%
# slope: -0.009050  intercept: 2.302956
# R-Squared: 0.002803

# %%
#high temp 30342

(slope, intercept, rvalue, pvalue, stderr) = linregress(HiTemp30342['Maximum Temperature'], HiTemp30342['Accident_ct'])
regress_values = slope * HiTemp30342['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(HiTemp30342['Maximum Temperature'], HiTemp30342['Accident_ct'])
plt.plot(HiTemp30342['Maximum Temperature'], regress_values, color = 'red',label = "High Temp fitted line")
plt.legend()
plt.annotate(line_eq,(75,7.2),fontsize=10,color="red")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30342")
corr=round(st.pearsonr(HiTemp30342['Maximum Temperature'], HiTemp30342['Accident_ct'])[0],2)*100
print(f"The correlation between High Temperature and accidents for zip code 30342 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)



#low temp 30342

(slope, intercept, rvalue, pvalue, stderr) = linregress(LoTemp30342['Maximum Temperature'], LoTemp30342['Accident_ct'])
regress_values = slope * LoTemp30342['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(LoTemp30342['Maximum Temperature'], LoTemp30342['Accident_ct'])
plt.plot(LoTemp30342['Maximum Temperature'], regress_values, color = "green",label = "Low Temp fitted line")
plt.legend()
plt.annotate(line_eq,(28,4.4),fontsize=10,color="green")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30342")
corr=round(st.pearsonr(LoTemp30342['Maximum Temperature'], LoTemp30342['Accident_ct'])[0],2)*100
print(f"The correlation between Low Temperature and accidents for zip code 30342 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between High Temperature and accidents for zip code 30342 is -6.0%
# slope: -0.022716  intercept: 3.033753
# R-Squared: 0.003757
# The correlation between Low Temperature and accidents for zip code 30342 is -3.0%
# slope: -0.002951  intercept: 1.299010
# R-Squared: 0.000641

# %%
#high temp 30318
(slope, intercept, rvalue, pvalue, stderr) = linregress(HiTemp30318['Maximum Temperature'], HiTemp30318['Accident_ct'])
regress_values = slope * HiTemp30318['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(HiTemp30318['Maximum Temperature'], HiTemp30318['Accident_ct'])
plt.plot(HiTemp30318['Maximum Temperature'], regress_values, color = 'red',label = "High Temp fitted line")
plt.legend()
plt.annotate(line_eq,(70,7),fontsize=10,color="red")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30318")
corr=round(st.pearsonr(HiTemp30318['Maximum Temperature'], HiTemp30318['Accident_ct'])[0],2)*100
print(f"The correlation between High Temperature and accidents for zip code 30318 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)



#low temp 30318

(slope, intercept, rvalue, pvalue, stderr) = linregress(LoTemp30318['Maximum Temperature'], LoTemp30318['Accident_ct'])
regress_values = slope * LoTemp30318['Maximum Temperature'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(LoTemp30318['Maximum Temperature'], LoTemp30318['Accident_ct'])
plt.plot(LoTemp30318['Maximum Temperature'], regress_values, color = "green",label = "Low Temp fitted line")
plt.legend()
plt.annotate(line_eq,(28,4.4),fontsize=10,color="green")
plt.xlabel("Temperature")
plt.ylabel("Accidents")
plt.title("Accident Data 30318")
corr=round(st.pearsonr(LoTemp30318['Maximum Temperature'], LoTemp30318['Accident_ct'])[0],2)*100
print(f"The correlation between Low Temperature and accidents for zip code 30318 is {corr}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between High Temperature and accidents for zip code 30318 is 1.0%
# slope: 0.004016  intercept: 0.870749
# R-Squared: 0.000107
# The correlation between Low Temperature and accidents for zip code 30318 is -13.0%
# slope: -0.015608  intercept: 2.226044
# R-Squared: 0.016248
