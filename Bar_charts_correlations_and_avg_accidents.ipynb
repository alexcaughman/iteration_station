# %%
#import dependencies
import csv
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
#dependencies needed for dual axes chart
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA

# %%
#reading in 30308_weather_traffic_FINAL from csv
# Csvpath = "weather_data2019_csv.csv"
zip30312 = "Weather_Traffic_Resources/30312_weather_traffic_FINAL.csv"
zip30339 = "Weather_Traffic_Resources/30339_weather_traffic_FINAL.csv"
zip30331 = "Weather_Traffic_Resources/30331_weather_traffic_FINAL.csv"
zip30315 = "Weather_Traffic_Resources/30315_weather_traffic_FINAL.csv"
zip30309 = "Weather_Traffic_Resources/30309_weather_traffic_FINAL.csv"
zip30340 = "Weather_Traffic_Resources/30340_weather_traffic_FINAL.csv"
zip30308 = "Weather_Traffic_Resources/30308_weather_traffic_FINAL.csv"
zip30324 = "Weather_Traffic_Resources/30324_weather_traffic_FINAL.csv"
zip30342 = "Weather_Traffic_Resources/30342_weather_traffic_FINAL.csv"
zip30318 = "Weather_Traffic_Resources/30318_weather_traffic_FINAL.csv"

zip30312_df = pd.read_csv(zip30312)
zip30339_df = pd.read_csv(zip30339)
zip30331_df = pd.read_csv(zip30331)
zip30315_df = pd.read_csv(zip30315)
zip30309_df = pd.read_csv(zip30309)
zip30340_df = pd.read_csv(zip30340)
zip30308_df = pd.read_csv(zip30308)
zip30324_df = pd.read_csv(zip30324)
zip30342_df = pd.read_csv(zip30342)
zip30318_df = pd.read_csv(zip30318)

print(zip30318_df)
# Out:
#      Unnamed: 0  Location  Address Country        Date  Maximum Temperature  \
# 0             0       NaN    30318     USA  01/01/2019                 64.8
# 1             1       NaN    30318     USA  01/02/2019                 56.7
# 2             2       NaN    30318     USA  01/03/2019                 54.6
# 3             3       NaN    30318     USA  01/04/2019                 64.0
# 4             4       NaN    30318     USA  01/05/2019                 57.5
# ..          ...       ...      ...     ...         ...                  ...
# 725         725       NaN    30318     USA  12/27/2018                 53.1
# 726         726       NaN    30318     USA  12/28/2018                 62.3
# 727         727       NaN    30318     USA  12/29/2018                 59.6
# 728         728       NaN    30318     USA  12/30/2018                 54.5
# 729         729       NaN    30318     USA  12/31/2018                 69.6
#
# ...

# %%
# summary_accidents_df = pd.DataFrame({"Zip 30318": [zip30318_df["Accident_ct"].sum())]})                                           })
zip30312count = zip30312_df["Accident_ct"].sum()
zip30339count = zip30339_df["Accident_ct"].sum()
zip30331count = zip30331_df["Accident_ct"].sum()
zip30315count = zip30315_df["Accident_ct"].sum()
zip30309count = zip30309_df["Accident_ct"].sum()
zip30340count = zip30340_df["Accident_ct"].sum()
zip30308count = zip30308_df["Accident_ct"].sum()
zip30324count = zip30324_df["Accident_ct"].sum()
zip30342count = zip30342_df["Accident_ct"].sum()
zip30318count = zip30318_df["Accident_ct"].sum()
sum10 = [zip30312count+zip30339count+zip30331count+zip30315count+zip30309count
             +zip30340count+zip30308count+zip30324count+zip30342count+zip30318count]
# print(sum10)
# sum10

average10=1238
averageATL=543
# print(zip30318_df["Accident_ct"].sum())
# print(zip30018count)
zipcount=[zip30312count,zip30339count,zip30331count,zip30315count,zip30309count,zip30340count,zip30308count,zip30324count,zip30342count,zip30318count]
# print(zipcount)
zips =['30312','30339','30331','30315','30309','30340','30308','30324','30342','30318']

x_axis = np.arange(1,11,1)
# print(zips)
# print(x_axis)

x_ticks_labels = ['30312','30339','30331','30315','30309','30340','30308','30324','30342','30318']

fig, ax = plt.subplots(1,1) 
plt.bar(x_axis,zipcount,color="b",alpha=.75, align="center")

# Set number of ticks for x-axis
ax.set_xticks(x_axis)
# Set ticks labels for x-axis
ax.set_xticklabels(x_ticks_labels, rotation=45)
plt.axhline(y=1238,linestyle='--',color='maroon')
plt.axhline(y=543,linestyle='--',color='aqua')
plt.ylabel('Total Accidents 2018-2019')
plt.title('Accidents by zip 2018-2019')
plt.text(6, 1400, 'Average of 10 ATL zips', style='italic', color='white',
        bbox={'facecolor': 'maroon', 'alpha': 1, 'pad': 7})
plt.text(6, 300, 'Average of all ATL zips', style='italic',
        bbox={'facecolor': 'aqua', 'alpha': 1, 'pad': 7})


plt.figure(figsize=(10,20))


fig.savefig("Images/Accidents_by_Zip_code.png")

# %%
# summary_accidents_df = pd.DataFrame({"Zip 30318": [zip30318_df["Accident_ct"].sum())]})                                           })
precip30312sum = zip30312_df["Precipitation"].sum()
precip30339sum = zip30339_df["Precipitation"].sum()
precip30331sum = zip30331_df["Precipitation"].sum()
precip30315sum = zip30315_df["Precipitation"].sum()
precip30309sum = zip30309_df["Precipitation"].sum()
precip30340sum = zip30340_df["Precipitation"].sum()
precip30308sum = zip30308_df["Precipitation"].sum()
precip30324sum = zip30324_df["Precipitation"].sum()
precip30342sum = zip30342_df["Precipitation"].sum()
precip30318sum = zip30318_df["Precipitation"].sum()
precipsum10 = [precip30312sum+precip30339sum+precip30331sum+precip30315sum+precip30309sum+
              precip30340sum+precip30308sum+precip30324sum+precip30342sum+precip30318sum]
print(precipsum10)
# sum10

precipaverage10=121
# averageATL=543
precipsum=[precip30312sum,precip30339sum,precip30331sum,precip30315sum,precip30309sum,
              precip30340sum,precip30308sum,precip30324sum,precip30342sum,precip30318sum]
# # print(zipcount)
# # zips =['30312','30339','30331','30315','30309','30340','30308','30324','30342','30318']
x_axis = np.arange(1,11,1)
# # print(zips)
# # print(x_axis)

x_ticks_labels = ['30312','30339','30331','30315','30309','30340','30308','30324','30342','30318']

fig, ax = plt.subplots(1,1) 
plt.bar(x_axis,precipsum,color="b",alpha=.75, align="center")

# # Set number of ticks for x-axis
ax.set_xticks(x_axis)
# Set ticks labels for x-axis
ax.set_xticklabels(x_ticks_labels, rotation=45)
plt.axhline(y=104,linestyle='--',color='aqua')
plt.axhline(y=121,linestyle='--',color='maroon')
plt.ylabel('Total Precipitaiton in inches 2018-2019')
plt.title('Precipitation in inches by zip 2018-2019')
plt.text(3, 130, 'Average of 10 ATL zips', style='italic', color='white',
        bbox={'facecolor': 'maroon', 'alpha': 1, 'pad': 7})
plt.text(6, 100, 'Historical Average ATL', style='italic',
        bbox={'facecolor': 'aqua', 'alpha': 1, 'pad': 7})


plt.figure(figsize=(10,20))
# Out:
# [1208.3]

# %%
# summary_accidents_df = pd.DataFrame({"Zip 30318": [zip30318_df["Accident_ct"].sum())]})                                           })
ws30312avg = zip30312_df["Wind Speed"].mean()
ws30339avg = zip30339_df["Wind Speed"].mean()
ws30331avg = zip30331_df["Wind Speed"].mean()
ws30315avg = zip30315_df["Wind Speed"].mean()
ws30309avg = zip30309_df["Wind Speed"].mean()
ws30340avg = zip30340_df["Wind Speed"].mean()
ws30308avg = zip30308_df["Wind Speed"].mean()
ws30324avg = zip30324_df["Wind Speed"].mean()
ws30342avg = zip30342_df["Wind Speed"].mean()
ws30318avg = zip30318_df["Wind Speed"].mean()


wsaverage10=121
# averageATL=543
wsavg=[ws30312avg,ws30339avg,ws30331avg,ws30315avg,ws30309avg,
              ws30340avg,ws30308avg,ws30324avg,ws30342avg,ws30318avg,]
# # print(zipcount)
# # zips =['30312','30339','30331','30315','30309','30340','30308','30324','30342','30318']
x_axis = np.arange(1,11,1)
# # print(zips)
# # print(x_axis)

x_ticks_labels = ['30312','30339','30331','30315','30309','30340','30308','30324','30342','30318']

fig, ax = plt.subplots(1,1) 
plt.bar(x_axis,wsavg,color="b",alpha=.75, align="center")

# # Set number of ticks for x-axis
ax.set_xticks(x_axis)
# Set ticks labels for x-axis
ax.set_xticklabels(x_ticks_labels, rotation=45)
# plt.axhline(y=10,linestyle='--',color='aqua')
# plt.axhline(y=121,linestyle='--',color='maroon')
plt.ylabel('Average WindSpeed in MPH 2018-2019')
plt.title('Average WindSpeed in MPH by zip 2018-2019')
# plt.text(3, 15, 'Average of 10 ATL zips', style='italic', color='white',
#         bbox={'facecolor': 'maroon', 'alpha': 1, 'pad': 7})
# plt.text(6, 100, 'Historical Average ATL', style='italic',
#         bbox={'facecolor': 'aqua', 'alpha': 1, 'pad': 7})


plt.figure(figsize=(10,20))

# %%
#accidents with precipitation
precip30312 = zip30312_df.loc[zip30312_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30339 = zip30339_df.loc[zip30339_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30331 = zip30331_df.loc[zip30331_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30315 = zip30315_df.loc[zip30315_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30309 = zip30309_df.loc[zip30309_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30340 = zip30340_df.loc[zip30340_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30308 = zip30308_df.loc[zip30308_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30324 = zip30324_df.loc[zip30324_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30342 = zip30342_df.loc[zip30342_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30318 = zip30318_df.loc[zip30318_df['Precipitation'] > 0,['Precipitation','Accident_ct']]

# precip30312

(slope, intercept, rvalue, pvalue, stderr) = linregress(precip30312['Precipitation'], precip30312['Accident_ct'])
regress_values = slope * precip30312['Precipitation'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(precip30312['Precipitation'], precip30312['Accident_ct'])
plt.plot(precip30312['Precipitation'], regress_values)
plt.annotate(line_eq,(1.5,15),fontsize=15,color="red")
plt.xlabel("Precip")
plt.ylabel("Accidents")
plt.title("Accident Data 30312")
corr=round(st.pearsonr(precip30312['Precipitation'], precip30312['Accident_ct'])[0],2)*100
print(f"The correlation between precip and accidents is {corr}%")
# Out:
# The correlation between precip and accidents is 16.0%

# %%
# precip30324

(slope, intercept, rvalue, pvalue, stderr) = linregress(precip30324['Precipitation'], precip30324['Accident_ct'])
regress_values = slope * precip30324['Precipitation'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(precip30324['Precipitation'], precip30324['Accident_ct'])
plt.plot(precip30324['Precipitation'], regress_values)
plt.annotate(line_eq,(2,5),fontsize=15,color="red")
plt.xlabel("Precip")
plt.ylabel("Accidents")
plt.title("Accident Data 30324")
corr=round(st.pearsonr(precip30324['Precipitation'], precip30324['Accident_ct'])[0],2)*100
print(f"The correlation between precip and accidents is {corr}%")
# Out:
# The correlation between precip and accidents is 0.0%

# %%
# list of correlations to days with precipitation and traffic accidents
pcorr30312=round(st.pearsonr(precip30312['Precipitation'], precip30312['Accident_ct'])[0],2)*100
pcorr30339=round(st.pearsonr(precip30339['Precipitation'], precip30339['Accident_ct'])[0],2)*100
pcorr30331=round(st.pearsonr(precip30331['Precipitation'], precip30331['Accident_ct'])[0],2)*100
pcorr30315=round(st.pearsonr(precip30315['Precipitation'], precip30315['Accident_ct'])[0],2)*100
pcorr30309=round(st.pearsonr(precip30309['Precipitation'], precip30309['Accident_ct'])[0],2)*100
pcorr30340=round(st.pearsonr(precip30340['Precipitation'], precip30340['Accident_ct'])[0],2)*100
pcorr30308=round(st.pearsonr(precip30308['Precipitation'], precip30308['Accident_ct'])[0],2)*100
pcorr30324=round(st.pearsonr(precip30324['Precipitation'], precip30324['Accident_ct'])[0],2)*100
pcorr30342=round(st.pearsonr(precip30342['Precipitation'], precip30342['Accident_ct'])[0],2)*100
pcorr30318=round(st.pearsonr(precip30318['Precipitation'], precip30318['Accident_ct'])[0],2)*100
pcorrlist=[pcorr30312,pcorr30339,pcorr30331,pcorr30315,pcorr30309,
              pcorr30340,pcorr30308,pcorr30324,pcorr30342,pcorr30318]

# list of correlations to all days and traffic accidents
corr30312=round(st.pearsonr(zip30312_df['Precipitation'], zip30312_df['Accident_ct'])[0],2)*100
corr30339=round(st.pearsonr(zip30339_df['Precipitation'], zip30339_df['Accident_ct'])[0],2)*100
corr30331=round(st.pearsonr(zip30331_df['Precipitation'], zip30331_df['Accident_ct'])[0],2)*100
corr30315=round(st.pearsonr(zip30315_df['Precipitation'], zip30315_df['Accident_ct'])[0],2)*100
corr30309=round(st.pearsonr(zip30309_df['Precipitation'], zip30309_df['Accident_ct'])[0],2)*100
corr30340=round(st.pearsonr(zip30340_df['Precipitation'], zip30340_df['Accident_ct'])[0],2)*100
corr30308=round(st.pearsonr(zip30308_df['Precipitation'], zip30308_df['Accident_ct'])[0],2)*100
corr30324=round(st.pearsonr(zip30324_df['Precipitation'], zip30324_df['Accident_ct'])[0],2)*100
corr30342=round(st.pearsonr(zip30342_df['Precipitation'], zip30342_df['Accident_ct'])[0],2)*100
corr30318=round(st.pearsonr(zip30318_df['Precipitation'], zip30318_df['Accident_ct'])[0],2)*100
corrlist=[corr30312,corr30339,corr30331,corr30315,corr30309,
              corr30340,corr30308,corr30324,corr30342,corr30318]



# print(corrlist)
# print(pcorrlist)


# Numbers of doubles of bars you want
N = 10

# Data on X-axis


blue_bar = (corrlist)
orange_bar = (pcorrlist)

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
plt.figure(figsize=(10,5))

# Width of a bar 
width = 0.3       

# Plotting
plt.bar(ind, blue_bar , width, label='Correlation')
plt.bar(ind + width, orange_bar, width, label='Correlation (days with Precipitation)')

plt.ylabel('Correlation %')
plt.title('Correlation of Precipitation and Accidents')

# xticks()
# First argument - A list of positions at which ticks should be placed
# Second argument -  A list of labels to place at the given locations
plt.xticks(ind + width/2 , (x_ticks_labels))

# Finding the best position for legends and putting it
plt.legend(loc='best')
plt.show()

# %%
# precip30342

(slope, intercept, rvalue, pvalue, stderr) = linregress(precip30342['Precipitation'], precip30342['Accident_ct'])
regress_values = slope * precip30342['Precipitation'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(precip30342['Precipitation'], precip30342['Accident_ct'])
plt.plot(precip30342['Precipitation'], regress_values)
plt.annotate(line_eq,(2,5),fontsize=15,color="red")
plt.xlabel("Precip")
plt.ylabel("Accidents")
plt.title("Accident Data 30342")
corr=round(st.pearsonr(precip30342['Precipitation'], precip30342['Accident_ct'])[0],2)*100
print(f"The correlation between precip and accidents is {corr}%")
# Out:
# The correlation between precip and accidents is 8.0%

# %%
# Create Averages of data on days with precipitation

precip30312_avgaccident = precip30312['Accident_ct'].mean()
precip30339_avgaccident = precip30339['Accident_ct'].mean()
precip30331_avgaccident = precip30331['Accident_ct'].mean()
precip30315_avgaccident = precip30315['Accident_ct'].mean()
precip30309_avgaccident = precip30309['Accident_ct'].mean()
precip30340_avgaccident = precip30340['Accident_ct'].mean()
precip30308_avgaccident = precip30308['Accident_ct'].mean()
precip30324_avgaccident = precip30324['Accident_ct'].mean()
precip30342_avgaccident = precip30342['Accident_ct'].mean()
precip30318_avgaccident = precip30318['Accident_ct'].mean()


print('30312 mean accidents with precipitation only '+str(precip30312_avgaccident))
print('30312 mean accidents All data '+str(zip30312_df["Accident_ct"].mean()))

print('30339 mean accidents with precipitation only '+str(precip30339_avgaccident))
print('30339 mean accidents All data '+str(zip30339_df["Accident_ct"].mean()))

print('30331 mean accidents with precipitation only '+str(precip30331_avgaccident))
print('30331 mean accidents All data '+str(zip30331_df["Accident_ct"].mean()))

print('30315 mean accidents with precipitation only '+str(precip30315_avgaccident))
print('30315 mean accidents All data '+str(zip30315_df["Accident_ct"].mean()))

print('30309 mean accidents with precipitation only '+str(precip30309_avgaccident))
print('30309 mean accidents All data '+str(zip30309_df["Accident_ct"].mean()))

print('30340 mean accidents with precipitation only '+str(precip30340_avgaccident))
print('30340 mean accidents All data '+str(zip30340_df["Accident_ct"].mean()))

print('30324 mean accidents with precipitation only '+str(precip30324_avgaccident))
print('30324 mean accidents All data '+str(zip30324_df["Accident_ct"].mean()))

print('30342 mean accidents with precipitation only '+str(precip30342_avgaccident))
print('30342 mean accidents All data '+str(zip30342_df["Accident_ct"].mean()))

print('30318 mean accidents with precipitation only '+str(precip30318_avgaccident))
print('30318 mean accidents All data '+str(zip30318_df["Accident_ct"].mean()))
# Out:
# 30312 mean accidents with precipitation only 3.3464912280701755
# 30312 mean accidents All data 2.664383561643836
# 30339 mean accidents with precipitation only 1.684873949579832
# 30339 mean accidents All data 1.5547945205479452
# 30331 mean accidents with precipitation only 1.9497716894977168
# 30331 mean accidents All data 1.680821917808219
# 30315 mean accidents with precipitation only 2.4732142857142856
# 30315 mean accidents All data 1.8493150684931507
# 30309 mean accidents with precipitation only 2.3580786026200875
# 30309 mean accidents All data 2.010958904109589
# 30340 mean accidents with precipitation only 1.6839622641509433
# 30340 mean accidents All data 1.4931506849315068
# 30324 mean accidents with precipitation only 1.6457399103139014
# 30324 mean accidents All data 1.663013698630137
# 30342 mean accidents with precipitation only 1.2387387387387387
# 30342 mean accidents All data 1.0876712328767124
# 30318 mean accidents with precipitation only 1.4934497816593886
# ...

# %%
# accidents without precipitation
NOprecip30312 = zip30312_df.loc[zip30312_df['Precipitation'] == 0,['Precipitation','Accident_ct']]
NOprecip30339 = zip30339_df.loc[zip30339_df['Precipitation'] == 0,['Precipitation','Accident_ct']]
NOprecip30331 = zip30331_df.loc[zip30331_df['Precipitation'] == 0,['Precipitation','Accident_ct']]
NOprecip30315 = zip30315_df.loc[zip30315_df['Precipitation'] == 0,['Precipitation','Accident_ct']]
NOprecip30309 = zip30309_df.loc[zip30309_df['Precipitation'] == 0,['Precipitation','Accident_ct']]
NOprecip30340 = zip30340_df.loc[zip30340_df['Precipitation'] == 0,['Precipitation','Accident_ct']]
NOprecip30308 = zip30308_df.loc[zip30308_df['Precipitation'] == 0,['Precipitation','Accident_ct']]
NOprecip30324 = zip30324_df.loc[zip30324_df['Precipitation'] == 0,['Precipitation','Accident_ct']]
NOprecip30342 = zip30342_df.loc[zip30342_df['Precipitation'] == 0,['Precipitation','Accident_ct']]
NOprecip30318 = zip30318_df.loc[zip30318_df['Precipitation'] == 0,['Precipitation','Accident_ct']]


NOprecip30312_avgaccident = NOprecip30312['Accident_ct'].mean()
NOprecip30339_avgaccident = NOprecip30339['Accident_ct'].mean()
NOprecip30331_avgaccident = NOprecip30331['Accident_ct'].mean()
NOprecip30315_avgaccident = NOprecip30315['Accident_ct'].mean()
NOprecip30309_avgaccident = NOprecip30309['Accident_ct'].mean()
NOprecip30340_avgaccident = NOprecip30340['Accident_ct'].mean()
NOprecip30308_avgaccident = NOprecip30308['Accident_ct'].mean()
NOprecip30324_avgaccident = NOprecip30324['Accident_ct'].mean()
NOprecip30342_avgaccident = NOprecip30342['Accident_ct'].mean()
NOprecip30318_avgaccident = NOprecip30318['Accident_ct'].mean()

# %%
print('30324 mean accidents with precipitation '+str(precip30324_avgaccident))
print('30324 mean accidents NO precipitation '+str(NOprecip30324_avgaccident))
print('30324 mean accidents All data '+str(zip30324_df["Accident_ct"].mean()))
# Out:
# 30324 mean accidents with precipitation 1.6457399103139014
# 30324 mean accidents NO precipitation 1.6706114398422092
# 30324 mean accidents All data 1.663013698630137

# %%
Average=[zip30312_df["Accident_ct"].mean(),
         zip30339_df["Accident_ct"].mean(),
         zip30331_df["Accident_ct"].mean(),
         zip30315_df["Accident_ct"].mean(),
         zip30309_df["Accident_ct"].mean(),
         zip30340_df["Accident_ct"].mean(),
         zip30308_df["Accident_ct"].mean(),
         zip30324_df["Accident_ct"].mean(),
         zip30342_df["Accident_ct"].mean(),
         zip30318_df["Accident_ct"].mean(),]

Average_Precip=[precip30312_avgaccident,
         precip30339_avgaccident,
         precip30331_avgaccident,
         precip30315_avgaccident,
         precip30309_avgaccident,
         precip30340_avgaccident,
         precip30308_avgaccident,
         precip30324_avgaccident,
         precip30342_avgaccident,
         precip30318_avgaccident,]


Average_NOPrecip=[NOprecip30312_avgaccident,
         NOprecip30339_avgaccident,
         NOprecip30331_avgaccident,
         NOprecip30315_avgaccident,
         NOprecip30309_avgaccident,
         NOprecip30340_avgaccident,
         NOprecip30308_avgaccident,
         NOprecip30324_avgaccident,
         NOprecip30342_avgaccident,
         NOprecip30318_avgaccident,]

# Average
# Average_Precip
# Average_N0precip


# Numbers of triples of bars you want
N = 10

# Data on X-axis


blue_bar = (Average)
orange_bar = (Average_Precip)
green_bar = (Average_NOPrecip)

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
# plt.figure(figsize=(10,5))

# Width of a bar 
width = 0.3       

# Plotting
plt.bar(ind, blue_bar , width, label='Average')
plt.bar(ind + width, orange_bar, width, label='Average with Precipitation')
plt.bar(ind + width + width, green_bar, width, label='Average without Precipitation')

plt.ylabel('Accidents per day')
plt.title('Average Accidents per day based on Precipitation')

# xticks()
# First argument - A list of positions at which ticks should be placed
# Second argument -  A list of labels to place at the given locations
plt.xticks(ind + width , (x_ticks_labels), rotation=45)

# Finding the best position for legends and putting it
plt.legend(loc='best')

plt.savefig("Images/Avg_Daily_Accidents_Precip.png")

# %%
HiWind30312 = zip30312_df.loc[zip30312_df['Wind Speed'] > 9,['Wind Speed','Accident_ct']]
HiWind30339 = zip30339_df.loc[zip30339_df['Wind Speed'] > 9,['Wind Speed','Accident_ct']]
HiWind30331 = zip30331_df.loc[zip30331_df['Wind Speed'] > 9,['Wind Speed','Accident_ct']]
HiWind30315 = zip30315_df.loc[zip30315_df['Wind Speed'] > 9,['Wind Speed','Accident_ct']]
HiWind30309 = zip30309_df.loc[zip30309_df['Wind Speed'] > 9,['Wind Speed','Accident_ct']]
HiWind30340 = zip30340_df.loc[zip30340_df['Wind Speed'] > 9,['Wind Speed','Accident_ct']]
HiWind30308 = zip30308_df.loc[zip30308_df['Wind Speed'] > 9,['Wind Speed','Accident_ct']]
HiWind30324 = zip30324_df.loc[zip30324_df['Wind Speed'] > 9,['Wind Speed','Accident_ct']]
HiWind30342 = zip30342_df.loc[zip30342_df['Wind Speed'] > 9,['Wind Speed','Accident_ct']]
HiWind30318 = zip30318_df.loc[zip30318_df['Wind Speed'] > 9,['Wind Speed','Accident_ct']]


Average=[zip30312_df["Accident_ct"].mean(),
         zip30339_df["Accident_ct"].mean(),
         zip30331_df["Accident_ct"].mean(),
         zip30315_df["Accident_ct"].mean(),
         zip30309_df["Accident_ct"].mean(),
         zip30340_df["Accident_ct"].mean(),
         zip30308_df["Accident_ct"].mean(),
         zip30324_df["Accident_ct"].mean(),
         zip30342_df["Accident_ct"].mean(),
         zip30318_df["Accident_ct"].mean(),]


HiWind30312_avgaccident = HiWind30312['Accident_ct'].mean()
HiWind30339_avgaccident = HiWind30339['Accident_ct'].mean()
HiWind30331_avgaccident = HiWind30331['Accident_ct'].mean()
HiWind30315_avgaccident = HiWind30315['Accident_ct'].mean()
HiWind30309_avgaccident = HiWind30309['Accident_ct'].mean()
HiWind30340_avgaccident = HiWind30340['Accident_ct'].mean()
HiWind30308_avgaccident = HiWind30308['Accident_ct'].mean()
HiWind30324_avgaccident = HiWind30324['Accident_ct'].mean()
HiWind30342_avgaccident = HiWind30342['Accident_ct'].mean()
HiWind30318_avgaccident = HiWind30318['Accident_ct'].mean()



Average_HiWind=[HiWind30312_avgaccident,
         HiWind30339_avgaccident,
         HiWind30331_avgaccident,
         HiWind30315_avgaccident,
         HiWind30309_avgaccident,
         HiWind30340_avgaccident,
         HiWind30308_avgaccident,
         HiWind30324_avgaccident,
         HiWind30342_avgaccident,
         HiWind30318_avgaccident,]

# Average
# Average_Precip
# Average_N0precip


# Numbers of doubles of bars you want
N = 10

# Data on X-axis


blue_bar = (Average)
orange_bar = (Average_HiWind)

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
plt.figure(figsize=(10,5))

# Width of a bar 
width = 0.3       

# Plotting
plt.bar(ind, blue_bar , width, label='Average')
plt.bar(ind + width, orange_bar, width, label='Average with High Wind')

plt.ylabel('Accidents per day')
plt.title('Average Accidents per day based on Wind Speed over 9 MPH')

# xticks()
# First argument - A list of positions at which ticks should be placed
# Second argument -  A list of labels to place at the given locations
plt.xticks(ind + width/2 , (x_ticks_labels))

# Finding the best position for legends and putting it
plt.legend(loc='best')
plt.show()

# %%
# windspeed30312

(slope, intercept, rvalue, pvalue, stderr) = linregress(HiWind30312['Wind Speed'], HiWind30312['Accident_ct'])
regress_values = slope * HiWind30312['Wind Speed'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(HiWind30312['Wind Speed'], HiWind30312['Accident_ct'])
plt.plot(HiWind30312['Wind Speed'], regress_values)
plt.annotate(line_eq,(10,15),fontsize=15,color="red")
plt.xlabel("Wind Speed")
plt.ylabel("Accidents")
plt.title("Accident Data 30312")
corr=round(st.pearsonr(HiWind30312['Wind Speed'], HiWind30312['Accident_ct'])[0],2)*100
print(f"The correlation between High Wind Speed and accidents is {corr}%")
# Out:
# The correlation between High Wind Speed and accidents is 11.0%

# %%
# windspeed30309

(slope, intercept, rvalue, pvalue, stderr) = linregress(HiWind30309['Wind Speed'], HiWind30309['Accident_ct'])
regress_values = slope * HiWind30309['Wind Speed'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(HiWind30309['Wind Speed'], HiWind30309['Accident_ct'])
plt.plot(HiWind30309['Wind Speed'], regress_values)
plt.annotate(line_eq,(10,10),fontsize=15,color="red")
plt.xlabel("Wind Speed")
plt.ylabel("Accidents")
plt.title("Accident Data 30309")
corr=round(st.pearsonr(HiWind30309['Wind Speed'], HiWind30309['Accident_ct'])[0],2)*100
print(f"The correlation between High Wind Speed and accidents is {corr}%")
# Out:
# The correlation between High Wind Speed and accidents is -2.0%

# %%
# list of correlations to all days and traffic accidents
wcorr30312=round(st.pearsonr(zip30312_df['Wind Speed'], zip30312_df['Accident_ct'])[0],2)*100
wcorr30339=round(st.pearsonr(zip30339_df['Wind Speed'], zip30339_df['Accident_ct'])[0],2)*100
wcorr30331=round(st.pearsonr(zip30331_df['Wind Speed'], zip30331_df['Accident_ct'])[0],2)*100
wcorr30315=round(st.pearsonr(zip30315_df['Wind Speed'], zip30315_df['Accident_ct'])[0],2)*100
wcorr30309=round(st.pearsonr(zip30309_df['Wind Speed'], zip30309_df['Accident_ct'])[0],2)*100
wcorr30340=round(st.pearsonr(zip30340_df['Wind Speed'], zip30340_df['Accident_ct'])[0],2)*100
wcorr30308=round(st.pearsonr(zip30308_df['Wind Speed'], zip30308_df['Accident_ct'])[0],2)*100
wcorr30324=round(st.pearsonr(zip30324_df['Wind Speed'], zip30324_df['Accident_ct'])[0],2)*100
wcorr30342=round(st.pearsonr(zip30342_df['Wind Speed'], zip30342_df['Accident_ct'])[0],2)*100
wcorr30318=round(st.pearsonr(zip30318_df['Wind Speed'], zip30318_df['Accident_ct'])[0],2)*100
wcorrlist=[wcorr30312,wcorr30339,wcorr30331,wcorr30315,wcorr30309,
              wcorr30340,wcorr30308,wcorr30324,wcorr30342,wcorr30318]


# print(wcorrlist)


# Numbers of bars you want
N = 10

# Data on X-axis


blue_bar = (wcorrlist)

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
plt.figure(figsize=(10,5))

# Width of a bar 
width = 0.3       

# Plotting
plt.bar(ind, blue_bar , width, label='Correlation')

plt.ylabel('Correlation %')
plt.title('Correlation of Wind Speed and Accidents')

# xticks()
# First argument - A list of positions at which ticks should be placed
# Second argument -  A list of labels to place at the given locations
plt.xticks(ind + width/2 , (x_ticks_labels))

# Finding the best position for legends and putting it
# plt.legend(loc='best')
plt.show()

# %%
# list of correlations to all days and traffic accidents
hcorr30312=round(st.pearsonr(zip30312_df['Relative Humidity'], zip30312_df['Accident_ct'])[0],2)*100
hcorr30339=round(st.pearsonr(zip30339_df['Relative Humidity'], zip30339_df['Accident_ct'])[0],2)*100
hcorr30331=round(st.pearsonr(zip30331_df['Relative Humidity'], zip30331_df['Accident_ct'])[0],2)*100
hcorr30315=round(st.pearsonr(zip30315_df['Relative Humidity'], zip30315_df['Accident_ct'])[0],2)*100
hcorr30309=round(st.pearsonr(zip30309_df['Relative Humidity'], zip30309_df['Accident_ct'])[0],2)*100
hcorr30340=round(st.pearsonr(zip30340_df['Relative Humidity'], zip30340_df['Accident_ct'])[0],2)*100
hcorr30308=round(st.pearsonr(zip30308_df['Relative Humidity'], zip30308_df['Accident_ct'])[0],2)*100
hcorr30324=round(st.pearsonr(zip30324_df['Relative Humidity'], zip30324_df['Accident_ct'])[0],2)*100
hcorr30342=round(st.pearsonr(zip30342_df['Relative Humidity'], zip30342_df['Accident_ct'])[0],2)*100
hcorr30318=round(st.pearsonr(zip30318_df['Relative Humidity'], zip30318_df['Accident_ct'])[0],2)*100
hcorrlist=[hcorr30312,hcorr30339,hcorr30331,hcorr30315,hcorr30309,
              hcorr30340,hcorr30308,hcorr30324,hcorr30342,hcorr30318]


# print(wcorrlist)


# Numbers of bars you want
N = 10

# Data on X-axis


blue_bar = (hcorrlist)

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
plt.figure(figsize=(10,5))

# Width of a bar 
width = 0.3       

# Plotting
plt.bar(ind, blue_bar , width, label='Correlation')

plt.ylabel('Correlation %')
plt.title('Correlation of Humidity with Accidents')

# xticks()
# First argument - A list of positions at which ticks should be placed
# Second argument -  A list of labels to place at the given locations
plt.xticks(ind + width/2 , (x_ticks_labels))

# Finding the best position for legends and putting it
# plt.legend(loc='best')
plt.show()

# %%
# Numbers of doubles of bars you want
N = 10

# Data on X-axis


blue_bar = (corrlist)
green_bar = (hcorrlist)

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
plt.figure(figsize=(10,5))

# Width of a bar 
width = 0.3       

# Plotting
plt.bar(ind, blue_bar , width, label='Correlation Precipitation and Accidents')
plt.bar(ind + width, green_bar, width, label='Correlation Humidity and Accidents')

plt.ylabel('Correlation %')
plt.title('Correlation Comparison')

# xticks()
# First argument - A list of positions at which ticks should be placed
# Second argument -  A list of labels to place at the given locations
plt.xticks(ind + width/2 , (x_ticks_labels))

# Finding the best position for legends and putting it
plt.legend(loc='best')

# %%
#getting average humidity for each zip code
hum1 = zip30312_df["Relative Humidity"].mean()
hum2 = zip30339_df["Relative Humidity"].mean()
hum3 = zip30331_df["Relative Humidity"].mean()
hum4 = zip30315_df["Relative Humidity"].mean()
hum5 = zip30309_df["Relative Humidity"].mean()
hum6 = zip30340_df["Relative Humidity"].mean()
hum7 = zip30308_df["Relative Humidity"].mean()
hum8 = zip30324_df["Relative Humidity"].mean()
hum9 = zip30342_df["Relative Humidity"].mean()
hum10 = zip30318_df["Relative Humidity"].mean()
hum_avg_list = [hum1,hum2,hum3,hum4,hum5,hum6,hum7,hum8,hum9,hum10]
sum(hum_avg_list)/10
min(hum_avg_list)
# Out:
# 68.55268493150683

# %%
#getting average precipitation for each zip code
precip1 = zip30312_df["Precipitation"].mean()
precip2 = zip30339_df["Precipitation"].mean()
precip3 = zip30331_df["Precipitation"].mean()
precip4 = zip30315_df["Precipitation"].mean()
precip5 = zip30309_df["Precipitation"].mean()
precip6 = zip30340_df["Precipitation"].mean()
precip7 = zip30308_df["Precipitation"].mean()
precip8 = zip30324_df["Precipitation"].mean()
precip9 = zip30342_df["Precipitation"].mean()
precip10 = zip30318_df["Precipitation"].mean()
precip_avg_list = [precip1,precip2,precip3,precip4,precip5,precip6,precip7,precip8,precip9,precip10]
sum(precip_avg_list)/10
# Out:
# 0.16552054794520543

# %%
#source: https://stackoverflow.com/questions/9103166/multiple-axis-in-matplotlib-with-different-scales
#source: https://matplotlib-users.narkive.com/CFYvNSPX/setting-the-tick-label-font-size

#create host subplot with axisartist.Axes that uses parasiteAxes.

plt.figure(figsize=(20,13))
host = host_subplot(111, axes_class=AA.Axes)
#correlation of precipitation and accidents
orange_bar = (pcorrlist)

#create additional axes on right with same x axis
par1 = host.twinx()
par2 = host.twinx()

#format new axes placement
new_fixed_axis1 = par1.get_grid_helper().new_fixed_axis
par1.axis["right"] = new_fixed_axis1(loc="right",
                                    axes=par1,
                                    offset=(0, 0))

new_fixed_axis = par2.get_grid_helper().new_fixed_axis
par2.axis["right"] = new_fixed_axis(loc="right",
                                    axes=par2,
                                    offset=(120, 0))

par2.axis["right"].toggle(all=True)

#set y limits for bar chart axis
host.set_ylim(-5, 37)

#set y limits for right axes
par1.set_ylim(.1, .2)
par2.set_ylim(65, 75)

#update name of xticks to zip codes
plt.xticks(ind, (x_ticks_labels))

#update axis labels
host.set_xlabel("Zip code", fontsize = 20)
host.set_ylabel("Correlation %")
par1.set_ylabel("Precipitation (in)")
par2.set_ylabel("Relative Humidity (%)")

#update font sizes
plt.ylabel('Correlation %', fontsize = 40)
plt.title('Correlation Comparison', fontsize = 40)

host.axis["left"].major_ticklabels.set_fontsize(20)
host.axis["bottom"].major_ticklabels.set_fontsize(20)
host.axis["left"].label.set_fontsize(30)
host.axis["bottom"].label.set_fontsize(30)

par1.axis["right"].major_ticklabels.set_fontsize(20)
par1.axis["right"].label.set_fontsize(30)

par2.axis["right"].label.set_fontsize(30)
par2.axis["right"].major_ticklabels.set_fontsize(20)

#plot bar chart
plt.bar(ind-(width/2), orange_bar , width, label='Correlation Precipitation and Accidents')
plt.bar(ind + (width/2), green_bar, width, label='Correlation Humidity and Accidents')

#plot line charts
p2, = par1.plot(ind, precip_avg_list, label="Precipitation Average", color = 'b')
p3, = par2.plot(ind,hum_avg_list , label="Relative Humidity Average", color = 'red')

#update axis colors
par1.axis["right"].label.set_color(p2.get_color())
par2.axis["right"].label.set_color(p3.get_color())

#plot legend
plt.legend(loc='upper center', fontsize = 25)

plt.tight_layout()

plt.savefig("Images/Correlation_Comparison_Humidity_Precipitation.png")
