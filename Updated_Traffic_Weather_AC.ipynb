# %%
#import dependencies
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
#reading in weather data from csv
Csvpath = "weather_data2018-19_csv.csv"
weather_data = pd.read_csv(Csvpath)
weather_data['Date time']= pd.to_datetime(weather_data['Date time']) 
weather_data['Date'] = weather_data['Date time'].dt.strftime('%m/%d/%Y')
weather_data = weather_data[['Location', 'Address', 'Country', 'Date', 'Maximum Temperature',
       'Minimum Temperature', 'Temperature', 'Wind Chill', 'Heat Index',
       'Precipitation', 'Snow Depth', 'Wind Speed', 'Wind Gust', 'Cloud Cover',
       'Relative Humidity', 'Conditions']]
weather_data
# Out:
#       Location  Address Country        Date  Maximum Temperature  \
# 0          NaN    30308     USA  01/01/2019                 64.9
# 1          NaN    30308     USA  01/02/2019                 56.8
# 2          NaN    30308     USA  01/03/2019                 54.4
# 3          NaN    30308     USA  01/04/2019                 64.6
# 4          NaN    30308     USA  01/05/2019                 57.5
# ...        ...      ...     ...         ...                  ...
# 7295       NaN    30308     USA  12/27/2018                 52.9
# 7296       NaN    30308     USA  12/28/2018                 62.0
# 7297       NaN    30308     USA  12/29/2018                 59.5
# 7298       NaN    30308     USA  12/30/2018                 54.3
# 7299       NaN    30308     USA  12/31/2018                 69.4
#
#       Minimum Temperature  Temperature  Wind Chill  Heat Index  Precipitation  \
# 0                    56.1         61.2         NaN         NaN            0.2
# ...

# %%
#reading in traffic data from csv Traffic csvs
Csvpath_30308 = "Traffic_Resources/30308_Traffic_data_final.csv"
Csvpath_30309 = "Traffic_Resources/30309_Traffic_data_final.csv"
Csvpath_30312 = "Traffic_Resources/30312_Traffic_data_final.csv"
Csvpath_30315 = "Traffic_Resources/30315_Traffic_data_final.csv"
Csvpath_30318 = "Traffic_Resources/30318_Traffic_data_final.csv"
Csvpath_30324 = "Traffic_Resources/30324_Traffic_data_final.csv"
Csvpath_30331 = "Traffic_Resources/30331_Traffic_data_final.csv"
Csvpath_30339 = "Traffic_Resources/30339_Traffic_data_final.csv"
Csvpath_30340 = "Traffic_Resources/30340_Traffic_data_final.csv"
Csvpath_30342 = "Traffic_Resources/30342_Traffic_data_final.csv"


traffic_data_30312 = pd.read_csv(Csvpath_30312)
traffic_data_30315 = pd.read_csv(Csvpath_30315)
traffic_data_30309 = pd.read_csv(Csvpath_30309)
traffic_data_30339 = pd.read_csv(Csvpath_30339)
traffic_data_30331 = pd.read_csv(Csvpath_30331)
traffic_data_30340 = pd.read_csv(Csvpath_30340)
traffic_data_30324 = pd.read_csv(Csvpath_30324)
traffic_data_30308 = pd.read_csv(Csvpath_30308)
traffic_data_30318 = pd.read_csv(Csvpath_30318)
traffic_data_30342 = pd.read_csv(Csvpath_30342)
traffic_data_30339
# Out:
#            Date  Severity_1  Severity_2  Severity_3  Severity_4  \
# 0    01/01/2018           0           0           0           0
# 1    01/02/2018           0           0           3           0
# 2    01/03/2018           0           0           0           0
# 3    01/04/2018           0           0           0           0
# 4    01/05/2018           0           0           0           0
# ..          ...         ...         ...         ...         ...
# 725  12/27/2019           0           0           0           0
# 726  12/28/2019           0           0           2           0
# 727  12/29/2019           0           1           2           0
# 728  12/30/2019           0           0           0           0
# 729  12/31/2019           0           0           0           0
#
#      Residential_ct  Interstate_ct  Accident_ct  Zipcode
# 0                 0              0            0    30339
# 1                 0              3            3    30339
# ...

# %%
#creating separate weather dataframes for each zipcode
weather_data_30312 = weather_data.loc[weather_data["Address"]==30312,:]
weather_data_30315 = weather_data.loc[weather_data["Address"]==30315,:]
weather_data_30309 = weather_data.loc[weather_data["Address"]==30309,:]
weather_data_30339 = weather_data.loc[weather_data["Address"]==30339,:]
weather_data_30331 = weather_data.loc[weather_data["Address"]==30331,:]
weather_data_30340 = weather_data.loc[weather_data["Address"]==30340,:]
weather_data_30324 = weather_data.loc[weather_data["Address"]==30324,:]
weather_data_30308 = weather_data.loc[weather_data["Address"]==30308,:]
weather_data_30318 = weather_data.loc[weather_data["Address"]==30318,:]
weather_data_30342 = weather_data.loc[weather_data["Address"]==30342,:]
weather_data_30315
# Out:
#       Location  Address Country        Date  Maximum Temperature  \
# 1095       NaN    30315     USA  01/01/2019                 65.4
# 1096       NaN    30315     USA  01/02/2019                 57.3
# 1097       NaN    30315     USA  01/03/2019                 54.6
# 1098       NaN    30315     USA  01/04/2019                 65.2
# 1099       NaN    30315     USA  01/05/2019                 58.3
# ...        ...      ...     ...         ...                  ...
# 5013       NaN    30315     USA  12/27/2018                 53.5
# 5014       NaN    30315     USA  12/28/2018                 62.2
# 5015       NaN    30315     USA  12/29/2018                 60.3
# 5016       NaN    30315     USA  12/30/2018                 54.8
# 5017       NaN    30315     USA  12/31/2018                 69.8
#
#       Minimum Temperature  Temperature  Wind Chill  Heat Index  Precipitation  \
# 1095                 56.9         62.0         NaN         NaN            0.2
# ...

# %%
#30312 traffic and weather merge
weather_traffic_30312 = pd.merge(weather_data_30312, traffic_data_30312, on = "Date", how = "left")
weather_traffic_30312["Accident_ct"].sum()
# Out:
# 1945

# %%
#30315 traffic and weather merge
weather_traffic_30315 = pd.merge(weather_data_30315, traffic_data_30315, on = "Date", how = "left")
#30309  traffic and weather merge
weather_traffic_30309 = pd.merge(weather_data_30309, traffic_data_30309, on = "Date", how = "left")
#30339 traffic and weather merge
weather_traffic_30339 = pd.merge(weather_data_30339, traffic_data_30339, on = "Date", how = "left")
#30331 traffic and weather merge
weather_traffic_30331 = pd.merge(weather_data_30331, traffic_data_30331, on = "Date", how = "left")
#30340 traffic and weather merge
weather_traffic_30340 = pd.merge(weather_data_30340, traffic_data_30340, on = "Date", how = "left")
#30324 traffic and weather merge
weather_traffic_30324 = pd.merge(weather_data_30324, traffic_data_30324, on = "Date", how = "left")
#30308 traffic and weather merge
weather_traffic_30308 = pd.merge(weather_data_30308, traffic_data_30308, on = "Date", how = "left")
#30318 traffic and weather merge
weather_traffic_30318 = pd.merge(weather_data_30318, traffic_data_30318, on = "Date", how = "left")
#30342 traffic and weather merge
weather_traffic_30342 = pd.merge(weather_data_30342, traffic_data_30342, on = "Date", how = "left")

# %%
test = weather_traffic_30318["Severity_1"].sum()+weather_traffic_30318["Severity_2"].sum()+weather_traffic_30318["Severity_3"].sum()+weather_traffic_30318["Severity_4"].sum()
test
# Out:
# 907

# %%
# weather_traffic_30312.to_csv('30312_weather_traffic_FINAL.csv',index = True, header = True)
# weather_traffic_30339.to_csv('30339_weather_traffic_FINAL.csv',index = True, header = True)
# weather_traffic_30331.to_csv('30331_weather_traffic_FINAL.csv',index = True, header = True)
# weather_traffic_30315.to_csv('30315_weather_traffic_FINAL.csv',index = True, header = True)
# weather_traffic_30309.to_csv('30309_weather_traffic_FINAL.csv',index = True, header = True)
# weather_traffic_30340.to_csv('30340_weather_traffic_FINAL.csv',index = True, header = True)
# weather_traffic_30308.to_csv('30308_weather_traffic_FINAL.csv',index = True, header = True)
# weather_traffic_30324.to_csv('30324_weather_traffic_FINAL.csv',index = True, header = True)
# weather_traffic_30342.to_csv('30342_weather_traffic_FINAL.csv',index = True, header = True)
# weather_traffic_30318.to_csv('30318_weather_traffic_FINAL.csv',index = True, header = True)

# %%
#Create Severity DataFrame
Severity30312 = {'Severity1': weather_traffic_30312["Severity_1"],
                        'Severity2': weather_traffic_30312["Severity_2"],
                        'Severity3': weather_traffic_30312["Severity_3"],
                        'Severity4': weather_traffic_30312["Severity_4"],
                        'Dates': weather_traffic_30312 ['Date']}
Severity30312_df = pd.DataFrame (Severity30312, columns = ['Severity1','Severity2','Severity3','Severity4','Dates'])

#Replace NaN Values with Zeroes
Severity30312_df.fillna(0, inplace=True)

#Convert 'Dates' to datetime format
Severity30312_df['Dates'] = Severity30312_df['Dates'].astype('datetime64[ns]')

#Sort 'Dates' to month/year
Severity30312_df['Dates'] = Severity30312_df['Dates'].dt.strftime('%Y/%m')
Severity30312_df.sort_values(by=['Dates'])

#Group by 'Dates'

Severity30312_df = Severity30312_df.groupby('Dates').sum()

#Print Severity DataFrame
Severity30312_df
# Out:
#          Severity1  Severity2  Severity3  Severity4
# Dates
# 2018/01          0         26         81          2
# 2018/02          0         17         54          0
# 2018/03          0         13         80          1
# 2018/04          0          6         46          0
# 2018/05          0          7         39          0
# 2018/06          0         20         87          0
# 2018/07          0         12         64          7
# 2018/08          0         30         94          1
# 2018/09          0         23         73          0
# 2018/10          0         30         62          3
# 2018/11          1         56         46          7
# 2018/12          0         35         57          3
# 2019/01          0         58         59          0
# 2019/02          0         65         47          5
# 2019/03          0         33         33          0
# 2019/04          0         52         50          4
# 2019/05          0         49         34          2
# ...

# %%
Severity30312_df.loc[:,['Severity1','Severity2','Severity3','Severity4']].plot.bar(stacked=True, color=(['g','b','orange','r']), figsize=(30,20))
plt.legend(loc = "upper right", fontsize = 20)
plt.title("Total 30312 Accident Severity Analysis", fontsize = 80)
plt.xlabel("Severity Level by Month", fontsize = 80)
plt.ylabel("Total Accidents", fontsize = 80)
plt.xticks(rotation=45,fontsize =30)
plt.yticks(fontsize =30)
plt.savefig("Images/Total_30312_Accident_Severity_Analysis.png")

# %%
#Create Severity DataFrame
Severity30339 = {'Severity1': weather_traffic_30339["Severity_1"],
                        'Severity2': weather_traffic_30339["Severity_2"],
                        'Severity3': weather_traffic_30339["Severity_3"],
                        'Severity4': weather_traffic_30339["Severity_4"],
                        'Dates': weather_traffic_30339 ['Date']}
Severity30339_df = pd.DataFrame (Severity30339, columns = ['Severity1','Severity2','Severity3','Severity4','Dates'])

#Replace NaN Values with Zeroes
Severity30339_df.fillna(0, inplace=True)

#Convert 'Dates' to datetime format
Severity30339_df['Dates'] = Severity30339_df['Dates'].astype('datetime64[ns]')

#Sort 'Dates' to month/year
Severity30339_df['Dates'] = Severity30339_df['Dates'].dt.strftime('%Y/%m')
Severity30339_df.sort_values(by=['Dates'])

#Group by 'Dates'

Severity30339_df = Severity30339_df.groupby('Dates').sum()

#Print Severity DataFrame
Severity30339_df
# Out:
#          Severity1  Severity2  Severity3  Severity4
# Dates
# 2018/01          0          9         30          0
# 2018/02          0          5         23          2
# 2018/03          0         10         21          1
# 2018/04          0         17         38          0
# 2018/05          0         10         29          1
# 2018/06          0          3         33          4
# 2018/07          0          2         27          0
# 2018/08          0          7         45          1
# 2018/09          0          7         33          1
# 2018/10          0         26         36         10
# 2018/11          0         17         28          1
# 2018/12          0         14         28          1
# 2019/01          0         19         30          2
# 2019/02          0         17         35         13
# 2019/03          0         12         27          0
# 2019/04          0         13         43          2
# 2019/05          0         22         28          0
# ...

# %%
Severity30339_df.loc[:,['Severity1','Severity2','Severity3','Severity4']].plot.bar(stacked=True, color=(['b','g','y','r']), figsize=(100,70))
plt.legend(loc = "upper right", fontsize = 70)
plt.title("Total 30339 Accident Severity Analysis", fontsize = 80)
plt.xlabel("Severity Level by Month", fontsize = 70)
plt.ylabel("Total Accidents", fontsize = 70)
plt.xticks(rotation=45,fontsize =60)
plt.yticks(fontsize =60)
plt.show()

# %%
#Create Severity DataFrame
Severity30331 = {'Severity1': weather_traffic_30331["Severity_1"],
                        'Severity2': weather_traffic_30331["Severity_2"],
                        'Severity3': weather_traffic_30331["Severity_3"],
                        'Severity4': weather_traffic_30331["Severity_4"],
                        'Dates': weather_traffic_30331 ['Date']}
Severity30331_df = pd.DataFrame (Severity30331, columns = ['Severity1','Severity2','Severity3','Severity4','Dates'])

#Replace NaN Values with Zeroes
Severity30331_df.fillna(0, inplace=True)

#Convert 'Dates' to datetime format
Severity30331_df['Dates'] = Severity30331_df['Dates'].astype('datetime64[ns]')

#Sort 'Dates' to month/year
Severity30331_df['Dates'] = Severity30331_df['Dates'].dt.strftime('%Y/%m')
Severity30331_df.sort_values(by=['Dates'])

#Group by 'Dates'

Severity30331_df = Severity30331_df.groupby('Dates').sum()

#Print Severity DataFrame
Severity30331_df
# Out:
#          Severity1  Severity2  Severity3  Severity4
# Dates
# 2018/01          0         16         37          1
# 2018/02          0         18         34          2
# 2018/03          0         16         37          2
# 2018/04          0          6         21          0
# 2018/05          0          5         29          4
# 2018/06          0         27         39          0
# 2018/07          0         17         33          3
# 2018/08          0         30         51          1
# 2018/09          0         14         30          2
# 2018/10          0         23         41          0
# 2018/11          0         37         26          4
# 2018/12          0         12         39          6
# 2019/01          0         20         32          3
# 2019/02          0         29         43          2
# 2019/03          0         14         35          8
# 2019/04          0         22         34          4
# 2019/05          0         31         30          9
# ...

# %%
Severity30331_df.loc[:,['Severity1','Severity2','Severity3','Severity4']].plot.bar(stacked=True, color=(['b','g','y','r']), figsize=(100,70))
plt.legend(loc = "upper right", fontsize = 70)
plt.title("Total 30331 Accident Severity Analysis", fontsize = 80)
plt.xlabel("Severity Level by Month", fontsize = 70)
plt.ylabel("Total Accidents", fontsize = 70)
plt.xticks(rotation=45,fontsize =60)
plt.yticks(fontsize =60)
plt.show()

# %%
#Create Severity DataFrame
Severity30315 = {'Severity1': weather_traffic_30315["Severity_1"],
                        'Severity2': weather_traffic_30315["Severity_2"],
                        'Severity3': weather_traffic_30315["Severity_3"],
                        'Severity4': weather_traffic_30315["Severity_4"],
                        'Dates': weather_traffic_30315 ['Date']}
Severity30315_df = pd.DataFrame (Severity30315, columns = ['Severity1','Severity2','Severity3','Severity4','Dates'])

#Replace NaN Values with Zeroes
Severity30315_df.fillna(0, inplace=True)

#Convert 'Dates' to datetime format
Severity30315_df['Dates'] = Severity30315_df['Dates'].astype('datetime64[ns]')

#Sort 'Dates' to month/year
Severity30315_df['Dates'] = Severity30315_df['Dates'].dt.strftime('%Y/%m')
Severity30315_df.sort_values(by=['Dates'])

#Group by 'Dates'

Severity30315_df = Severity30315_df.groupby('Dates').sum()

#Print Severity DataFrame
Severity30315_df
# Out:
#          Severity1  Severity2  Severity3  Severity4
# Dates
# 2018/01          0         15         41          2
# 2018/02          0         18         46          1
# 2018/03          0         26         49          1
# 2018/04          0          9         30          9
# 2018/05          0         13         32          2
# 2018/06          0         29         54          1
# 2018/07          0         13         26          0
# 2018/08          0         20         67          5
# 2018/09          0         21         31          3
# 2018/10          0         33         33          7
# 2018/11          0         43         39          4
# 2018/12          0         26         51          8
# 2019/01          0         38         26          2
# 2019/02          0         42         25          8
# 2019/03          0         29         26         13
# 2019/04          0         29         27          6
# 2019/05          0         25         25          9
# ...

# %%
Severity30315_df.loc[:,['Severity1','Severity2','Severity3','Severity4']].plot.bar(stacked=True, color=(['b','g','y','r']), figsize=(100,70))
plt.legend(loc = "upper right", fontsize = 70)
plt.title("Total 30315 Accident Severity Analysis", fontsize = 80)
plt.xlabel("Severity Level by Month", fontsize = 70)
plt.ylabel("Total Accidents", fontsize = 70)
plt.xticks(rotation=45,fontsize =60)
plt.yticks(fontsize =60)
plt.show()

# %%
#Create Severity DataFrame
Severity30309 = {'Severity1': weather_traffic_30309["Severity_1"],
                        'Severity2': weather_traffic_30309["Severity_2"],
                        'Severity3': weather_traffic_30309["Severity_3"],
                        'Severity4': weather_traffic_30309["Severity_4"],
                        'Dates': weather_traffic_30309 ['Date']}
Severity30309_df = pd.DataFrame (Severity30309, columns = ['Severity1','Severity2','Severity3','Severity4','Dates'])

#Replace NaN Values with Zeroes
Severity30309_df.fillna(0, inplace=True)

#Convert 'Dates' to datetime format
Severity30309_df['Dates'] = Severity30309_df['Dates'].astype('datetime64[ns]')

#Sort 'Dates' to month/year
Severity30309_df['Dates'] = Severity30309_df['Dates'].dt.strftime('%Y/%m')
Severity30309_df.sort_values(by=['Dates'])

#Group by 'Dates'

Severity30309_df = Severity30309_df.groupby('Dates').sum()

#Print Severity DataFrame
Severity30309_df
# Out:
#          Severity1  Severity2  Severity3  Severity4
# Dates
# 2018/01          0         22         47          6
# 2018/02          0         28         70          1
# 2018/03          0         18         41          0
# 2018/04          0          0         49          1
# 2018/05          0          7         44          0
# 2018/06          0         36         57          4
# 2018/07          0         20         47          0
# 2018/08          0         39         60          3
# 2018/09          0         22         59          2
# 2018/10          0         40         46          0
# 2018/11          0         41         43          0
# 2018/12          0         16         27          0
# 2019/01          0         51         33          2
# 2019/02          0         41         18          2
# 2019/03          0         26         18          3
# 2019/04          0         27         21          0
# 2019/05          0         45         25          6
# ...

# %%
Severity30309_df.loc[:,['Severity1','Severity2','Severity3','Severity4']].plot.bar(stacked=True, color=(['b','g','y','r']), figsize=(100,70))
plt.legend(loc = "upper right", fontsize = 70)
plt.title("Total 30309 Accident Severity Analysis", fontsize = 80)
plt.xlabel("Severity Level by Month", fontsize = 70)
plt.ylabel("Total Accidents", fontsize = 70)
plt.xticks(rotation=45,fontsize =60)
plt.yticks(fontsize =60)
plt.show()

# %%
#Create Severity DataFrame
Severity30340 = {'Severity1': weather_traffic_30340["Severity_1"],
                        'Severity2': weather_traffic_30340["Severity_2"],
                        'Severity3': weather_traffic_30340["Severity_3"],
                        'Severity4': weather_traffic_30340["Severity_4"],
                        'Dates': weather_traffic_30340 ['Date']}
Severity30340_df = pd.DataFrame (Severity30340, columns = ['Severity1','Severity2','Severity3','Severity4','Dates'])

#Replace NaN Values with Zeroes
Severity30340_df.fillna(0, inplace=True)

#Convert 'Dates' to datetime format
Severity30340_df['Dates'] = Severity30340_df['Dates'].astype('datetime64[ns]')

#Sort 'Dates' to month/year
Severity30340_df['Dates'] = Severity30340_df['Dates'].dt.strftime('%Y/%m')
Severity30340_df.sort_values(by=['Dates'])

#Group by 'Dates'

Severity30340_df = Severity30340_df.groupby('Dates').sum()

#Print Severity DataFrame
Severity30340_df
# Out:
#          Severity1  Severity2  Severity3  Severity4
# Dates
# 2018/01          0          8         40          3
# 2018/02          0          6         37          2
# 2018/03          0         10         26          0
# 2018/04          0          8         29          3
# 2018/05          0         12         25          4
# 2018/06          0          5         26          0
# 2018/07          0          4         26          0
# 2018/08          0         23         50          8
# 2018/09          0         11         19          2
# 2018/10          0         23         40          1
# 2018/11          0         27         29          6
# 2018/12          0         23         35          5
# 2019/01          0         21         18          0
# 2019/02          0         27         22          0
# 2019/03          0         19         18          5
# 2019/04          0         11         23          5
# 2019/05          0          6         28          1
# ...

# %%
Severity30340_df.loc[:,['Severity1','Severity2','Severity3','Severity4']].plot.bar(stacked=True, color=(['b','g','y','r']), figsize=(100,70))
plt.legend(loc = "upper right", fontsize = 70)
plt.title("Total 30340 Accident Severity Analysis", fontsize = 80)
plt.xlabel("Severity Level by Month", fontsize = 70)
plt.ylabel("Total Accidents", fontsize = 70)
plt.xticks(rotation=45,fontsize =60)
plt.yticks(fontsize =60)
plt.show()

# %%
#Create Severity DataFrame
Severity30308 = {'Severity1': weather_traffic_30308["Severity_1"],
                        'Severity2': weather_traffic_30308["Severity_2"],
                        'Severity3': weather_traffic_30308["Severity_3"],
                        'Severity4': weather_traffic_30308["Severity_4"],
                        'Dates': weather_traffic_30308 ['Date']}
Severity30308_df = pd.DataFrame (Severity30308, columns = ['Severity1','Severity2','Severity3','Severity4','Dates'])

#Replace NaN Values with Zeroes
Severity30308_df.fillna(0, inplace=True)

#Convert 'Dates' to datetime format
Severity30308_df['Dates'] = Severity30308_df['Dates'].astype('datetime64[ns]')

#Sort 'Dates' to month/year
Severity30308_df['Dates'] = Severity30308_df['Dates'].dt.strftime('%Y/%m')
Severity30308_df.sort_values(by=['Dates'])

#Group by 'Dates'

Severity30308_df = Severity30308_df.groupby('Dates').sum()

#Print Severity DataFrame
Severity30308_df
# Out:
#          Severity1  Severity2  Severity3  Severity4
# Dates
# 2018/01          0         24         36          0
# 2018/02          0         19         52          0
# 2018/03          0         30         29          1
# 2018/04          0          4         19          0
# 2018/05          0          5         16          0
# 2018/06          0         32         49          0
# 2018/07          0         34         31          0
# 2018/08          0         29         32          0
# 2018/09          0         28         38          0
# 2018/10          0         27         35          2
# 2018/11          0         41         27          0
# 2018/12          0         20         19          2
# 2019/01          0         43         37          0
# 2019/02          1         33         25          0
# 2019/03          0         30         21          0
# 2019/04          0         38         25          2
# 2019/05          0         41         18          3
# ...

# %%
Severity30308_df.loc[:,['Severity1','Severity2','Severity3','Severity4']].plot.bar(stacked=True, color=(['b','g','y','r']), figsize=(100,70))
plt.legend(loc = "upper right", fontsize = 70)
plt.title("Total 30308 Accident Severity Analysis", fontsize = 80)
plt.xlabel("Severity Level by Month", fontsize = 70)
plt.ylabel("Total Accidents", fontsize = 70)
plt.xticks(rotation=45,fontsize =60)
plt.yticks(fontsize =60)
plt.show()

# %%
#Create Severity DataFrame
Severity30324 = {'Severity1': weather_traffic_30324["Severity_1"],
                        'Severity2': weather_traffic_30324["Severity_2"],
                        'Severity3': weather_traffic_30324["Severity_3"],
                        'Severity4': weather_traffic_30324["Severity_4"],
                        'Dates': weather_traffic_30324 ['Date']}
Severity30324_df = pd.DataFrame (Severity30324, columns = ['Severity1','Severity2','Severity3','Severity4','Dates'])

#Replace NaN Values with Zeroes
Severity30324_df.fillna(0, inplace=True)

#Convert 'Dates' to datetime format
Severity30324_df['Dates'] = Severity30324_df['Dates'].astype('datetime64[ns]')

#Sort 'Dates' to month/year
Severity30324_df['Dates'] = Severity30324_df['Dates'].dt.strftime('%Y/%m')
Severity30324_df.sort_values(by=['Dates'])

#Group by 'Dates'

Severity30324_df = Severity30324_df.groupby('Dates').sum()

#Print Severity DataFrame
Severity30324_df
# Out:
#          Severity1  Severity2  Severity3  Severity4
# Dates
# 2018/01          0         31         41          0
# 2018/02          0         21         27          0
# 2018/03          0         25         32          0
# 2018/04          0         11         18          3
# 2018/05          0         16         15          0
# 2018/06          0         30         30          0
# 2018/07          0         17         29          0
# 2018/08          0         38         51          1
# 2018/09          0         20         25          0
# 2018/10          0         47         45          2
# 2018/11          0         42         32          0
# 2018/12          0         27         26          3
# 2019/01          0         56         34          0
# 2019/02          0         34         13          1
# 2019/03          0         34         17          1
# 2019/04          0         40         18          1
# 2019/05          0         51         20          0
# ...

# %%
Severity30324_df.loc[:,['Severity1','Severity2','Severity3','Severity4']].plot.bar(stacked=True, color=(['b','g','y','r']), figsize=(100,70))
plt.legend(loc = "upper right", fontsize = 70)
plt.title("Total 30324 Accident Severity Analysis", fontsize = 80)
plt.xlabel("Severity Level by Month", fontsize = 70)
plt.ylabel("Total Accidents", fontsize = 70)
plt.xticks(rotation=45,fontsize =60)
plt.yticks(fontsize =60)
plt.show()

# %%
#Create Severity DataFrame
Severity30342 = {'Severity1': weather_traffic_30342["Severity_1"],
                        'Severity2': weather_traffic_30342["Severity_2"],
                        'Severity3': weather_traffic_30342["Severity_3"],
                        'Severity4': weather_traffic_30342["Severity_4"],
                        'Dates': weather_traffic_30342 ['Date']}
Severity30342_df = pd.DataFrame (Severity30342, columns = ['Severity1','Severity2','Severity3','Severity4','Dates'])

#Replace NaN Values with Zeroes
Severity30342_df.fillna(0, inplace=True)

#Convert 'Dates' to datetime format
Severity30342_df['Dates'] = Severity30342_df['Dates'].astype('datetime64[ns]')

#Sort 'Dates' to month/year
Severity30342_df['Dates'] = Severity30342_df['Dates'].dt.strftime('%Y/%m')
Severity30342_df.sort_values(by=['Dates'])

#Group by 'Dates'

Severity30342_df = Severity30342_df.groupby('Dates').sum()

#Print Severity DataFrame
Severity30342_df
# Out:
#          Severity1  Severity2  Severity3  Severity4
# Dates
# 2018/01          0         22          6          0
# 2018/02          0         25          3          2
# 2018/03          0         17          7          0
# 2018/04          0         11          7          0
# 2018/05          0         14          8          0
# 2018/06          0         19          6          1
# 2018/07          0         16          7          1
# 2018/08          0         31          6          1
# 2018/09          0         12          3          1
# 2018/10          0         31          9          0
# 2018/11          0         35         11          3
# 2018/12          0         22         15          6
# 2019/01          0         27         15          0
# 2019/02          0         20         20          8
# 2019/03          0         14         14          0
# 2019/04          0         12          5          4
# 2019/05          0         26         23          1
# ...

# %%
Severity30342_df.loc[:,['Severity1','Severity2','Severity3','Severity4']].plot.bar(stacked=True, color=(['b','g','y','r']), figsize=(100,70))
plt.legend(loc = "upper right", fontsize = 70)
plt.title("Total 30342 Accident Severity Analysis", fontsize = 80)
plt.xlabel("Severity Level by Month", fontsize = 70)
plt.ylabel("Total Accidents", fontsize = 70)
plt.xticks(rotation=45,fontsize =60)
plt.yticks(fontsize =60)
plt.show()

# %%
#Create Severity DataFrame
Severity30318 = {'Severity1': weather_traffic_30318["Severity_1"],
                        'Severity2': weather_traffic_30318["Severity_2"],
                        'Severity3': weather_traffic_30318["Severity_3"],
                        'Severity4': weather_traffic_30318["Severity_4"],
                        'Dates': weather_traffic_30318 ['Date']}
Severity30318_df = pd.DataFrame (Severity30318, columns = ['Severity1','Severity2','Severity3','Severity4','Dates'])

#Replace NaN Values with Zeroes
Severity30318_df.fillna(0, inplace=True)

#Convert 'Dates' to datetime format
Severity30318_df['Dates'] = Severity30318_df['Dates'].astype('datetime64[ns]')

#Sort 'Dates' to month/year
Severity30318_df['Dates'] = Severity30318_df['Dates'].dt.strftime('%Y/%m')
Severity30318_df.sort_values(by=['Dates'])

#Group by 'Dates'

Severity30318_df = Severity30318_df.groupby('Dates').sum()

#Print Severity DataFrame
Severity30318_df
# Out:
#          Severity1  Severity2  Severity3  Severity4
# Dates
# 2018/01          0          7         42          2
# 2018/02          0          3         35          1
# 2018/03          0         10         23          0
# 2018/04          0          8         18          0
# 2018/05          0          2         13          2
# 2018/06          0          7         34          1
# 2018/07          0          9         39          0
# 2018/08          0         18         48          2
# 2018/09          0          7         31          3
# 2018/10          0         16         36          1
# 2018/11          0         29         28          0
# 2018/12          0         17         17          1
# 2019/01          0         28         21          0
# 2019/02          1         26         21          4
# 2019/03          0         13         10          2
# 2019/04          0          9         13          4
# 2019/05          0         19         16          4
# ...

# %%
Severity30318_df.loc[:,['Severity1','Severity2','Severity3','Severity4']].plot.bar(stacked=True, color=(['b','g','y','r']), figsize=(100,70))
plt.legend(loc = "upper right", fontsize = 70)
plt.title("Total 30318 Accident Severity Analysis", fontsize = 80)
plt.xlabel("Severity Level by Month", fontsize = 70)
plt.ylabel("Total Accidents", fontsize = 70)
plt.xticks(rotation=45,fontsize =60)
plt.yticks(fontsize =60)
plt.show()
