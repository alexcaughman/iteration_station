# %% [markdown]
# Weather call experimentation

# %%
# Dependencies and Setup
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import scipy.stats as st
from pprint import pprint
import datetime

x = datetime.datetime.now()
print(x)

# Import API key
from api_keys import weather_api_key
from api_keys import vc_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
# Out:
# 2020-06-30 08:02:15.851024

# %% [markdown]
# ## Marietta at I-75

# %%
# Marietta I-75
lat = 33.946706
lon = -84.513774


city = citipy.nearest_city(lat, lon).city_name
country = citipy.nearest_city(lat,lon).country_code

from datetime import timezone
starttime = datetime.datetime(2019, 5, 15)
start = starttime.replace(tzinfo=timezone.utc).timestamp()
endtime = datetime.datetime(2019, 5, 16)
end = endtime.replace(tzinfo=timezone.utc).timestamp()

print(start)
print(end)

print(city)
print(country)
# Out:
# 1557878400.0
# 1557964800.0
# marietta
# us

# %%
### Perform API Calls

# API call:

# query_url = 'http://history.openweathermap.org/data/2.5/history/city?lat={lat}&lon={lon}&type=hour&start={start}&end={end}&appid={weather_api_key}'



# response = requests.get(query_url).json()

# pprint(response)

# %%
### Perform API Calls
#visual crossing weather API - Daily average - 5 locations - Marietta, Norcross, Sandy Springs, Lithonia, Austell

print(vc_key)

# API call:

query_url =  'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/history?aggregateHours=24&combinationMethod=aggregate&startDateTime=2019-05-13T00%3A00%3A00&endDateTime=2019-05-17T00%3A00%3A00&collectStationContributions=false&maxStations=-1&maxDistance=-1&includeNormals=false&contentType=json&unitGroup=us&locationMode=array&key=UAK6GM3LUGAXP1E4TET3KS0KJ&locations=marietta%20GA%7CNorcross%20GA%7CSandy%20Springs%20GA%7CLithonia%20GA%7Caustell%20GA'
response = requests.get(query_url).json()

pprint(response)
# Out:
# UAK6GM3LUGAXP1E4TET3KS0KJ
# {'columns': {'address': {'id': 'address',
#                          'name': 'Address',
#                          'type': 1,
#                          'unit': None},
#              'cloudcover': {'id': 'cloudcover',
#                             'name': 'Cloud Cover',
#                             'type': 2,
#                             'unit': '%'},
#              'conditions': {'id': 'conditions',
#                             'name': 'Conditions',
#                             'type': 1,
#                             'unit': None},
#              'datetime': {'id': 'datetime',
#                           'name': 'Date time',
#                           'type': 3,
#                           'unit': None},
#              'dew': {'id': 'dew',
#                      'name': 'Dew Point',
#                      'type': 2,
#                      'unit': 'degF'},
#              'heatindex': {'id': 'heatindex',
# ...
