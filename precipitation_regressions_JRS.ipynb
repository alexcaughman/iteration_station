# %%
#import dependencies
import csv
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# %%
#read in zip csv's
zip30312 = "30312_weather_traffic_FINAL.csv"
zip30339 = "30339_weather_traffic_FINAL.csv"
zip30331 = "30331_weather_traffic_FINAL.csv"
zip30315 = "30315_weather_traffic_FINAL.csv"
zip30309 = "30309_weather_traffic_FINAL.csv"
zip30340 = "30340_weather_traffic_FINAL.csv"
zip30308 = "30308_weather_traffic_FINAL.csv"
zip30324 = "30324_weather_traffic_FINAL.csv"
zip30342 = "30342_weather_traffic_FINAL.csv"
zip30318 = "30318_weather_traffic_FINAL.csv"

zip30312_df = pd.read_csv(zip30312)
zip30339_df = pd.read_csv(zip30339)
zip30331_df = pd.read_csv(zip30331)
zip30315_df = pd.read_csv(zip30315)
zip30309_df = pd.read_csv(zip30309)
zip30340_df = pd.read_csv(zip30340)
zip30308_df = pd.read_csv(zip30308)
zip30324_df = pd.read_csv(zip30324)
zip30342_df = pd.read_csv(zip30342)
zip30318_df = pd.read_csv(zip30318)

zip30312_df.head()
# Out:
#    Unnamed: 0  Location  Address Country        Date  Maximum Temperature  \
# 0           0       NaN    30312     USA  01/01/2019                 65.1
# 1           1       NaN    30312     USA  01/02/2019                 57.0
# 2           2       NaN    30312     USA  01/03/2019                 54.3
# 3           3       NaN    30312     USA  01/04/2019                 64.8
# 4           4       NaN    30312     USA  01/05/2019                 57.8
#
#    Minimum Temperature  Temperature  Wind Chill  Heat Index  ...  \
# 0                 56.4         61.5         NaN         NaN  ...
# 1                 49.0         52.4        46.3         NaN  ...
# 2                 50.1         52.5         NaN         NaN  ...
# 3                 45.1         54.5        40.1         NaN  ...
# 4                 43.7         48.8        36.4         NaN  ...
#
#    Relative Humidity              Conditions  Severity_1  Severity_2  \
# ...

# %%
# accident with rain
precip30312 = zip30312_df.loc[zip30312_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30339 = zip30339_df.loc[zip30339_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30331 = zip30331_df.loc[zip30331_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30315 = zip30315_df.loc[zip30315_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30309 = zip30309_df.loc[zip30309_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30340 = zip30340_df.loc[zip30340_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30308 = zip30308_df.loc[zip30308_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30324 = zip30324_df.loc[zip30324_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30342 = zip30342_df.loc[zip30342_df['Precipitation'] > 0,['Precipitation','Accident_ct']]
precip30318 = zip30318_df.loc[zip30318_df['Precipitation'] > 0,['Precipitation','Accident_ct']]

# %%
# rain 30312
(slope, intercept, rvalue, pvalue, stderr) = linregress(precip30312['Precipitation'], precip30312['Accident_ct'])
regress_values = slope * precip30312['Precipitation'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(precip30312['Precipitation'], precip30312['Accident_ct'])
plt.plot(precip30312['Precipitation'], regress_values, color = 'red')
plt.annotate(line_eq,(1.5,15),fontsize=15,color="red")
plt.xlabel("Precip")
plt.ylabel("Accidents")
plt.title("Accident Data 30312")
rain_corr_30312=round(st.pearsonr(precip30312['Precipitation'], precip30312['Accident_ct'])[0],2)*100
print(f"The correlation between precip and accidents is for zip code 30312 is {rain_corr_30312}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between precip and accidents is for zip code 30312 is 16.0%
# slope: 0.783597  intercept: 2.952974
# R-Squared: 0.026804

# %%
# rain 30339
(slope, intercept, rvalue, pvalue, stderr) = linregress(precip30339['Precipitation'], precip30339['Accident_ct'])
regress_values = slope * precip30339['Precipitation'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(precip30339['Precipitation'], precip30339['Accident_ct'])
plt.plot(precip30339['Precipitation'], regress_values, color = 'red')
plt.annotate(line_eq,(1.5,15),fontsize=15,color="red")
plt.xlabel("Precip")
plt.ylabel("Accidents")
plt.title("Accident Data 30339")
rain_corr_30339=round(st.pearsonr(precip30339['Precipitation'], precip30339['Accident_ct'])[0],2)*100
print(f"The correlation between precip and accidents for zip code 30339 is {rain_corr_30339}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between precip and accidents for zip code 30339 is 2.0%
# slope: 0.083694  intercept: 1.637225
# R-Squared: 0.000611

# %%
# rain 30331
(slope, intercept, rvalue, pvalue, stderr) = linregress(precip30331['Precipitation'], precip30331['Accident_ct'])
regress_values = slope * precip30331['Precipitation'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(precip30331['Precipitation'], precip30331['Accident_ct'])
plt.plot(precip30331['Precipitation'], regress_values, color = 'red')
plt.annotate(line_eq,(1.5,7),fontsize=15,color="red")
plt.xlabel("Precip")
plt.ylabel("Accidents")
plt.title("Accident Data 30331")
rain_corr_30331=round(st.pearsonr(precip30331['Precipitation'], precip30331['Accident_ct'])[0],2)*100
print(f"The correlation between precip and accidents for zip code 30331 is {rain_corr_30331}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between precip and accidents for zip code 30331 is 19.0%
# slope: 0.506019  intercept: 1.678277
# R-Squared: 0.036972

# %%
# rain 30315
(slope, intercept, rvalue, pvalue, stderr) = linregress(precip30315['Precipitation'], precip30315['Accident_ct'])
regress_values = slope * precip30315['Precipitation'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(precip30315['Precipitation'], precip30315['Accident_ct'])
plt.plot(precip30315['Precipitation'], regress_values, color = 'red')
plt.annotate(line_eq,(1.5,10),fontsize=15,color="red")
plt.xlabel("Precip")
plt.ylabel("Accidents")
plt.title("Accident Data 30315")
rain_corr_30315=round(st.pearsonr(precip30315['Precipitation'], precip30315['Accident_ct'])[0],2)*100
print(f"The correlation between precip and accidents for zip code 30315 is {rain_corr_30315}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between precip and accidents for zip code 30315 is 3.0%
# slope: 0.112846  intercept: 2.415734
# R-Squared: 0.000732

# %%
# rain 30309
(slope, intercept, rvalue, pvalue, stderr) = linregress(precip30309['Precipitation'], precip30309['Accident_ct'])
regress_values = slope * precip30309['Precipitation'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(precip30309['Precipitation'], precip30309['Accident_ct'])
plt.plot(precip30309['Precipitation'], regress_values, color = "red")
plt.annotate(line_eq,(1.5,7),fontsize=15,color="red")
plt.xlabel("Precip")
plt.ylabel("Accidents")
plt.title("Accident Data 30309")
rain_corr_30309=round(st.pearsonr(precip30309['Precipitation'], precip30309['Accident_ct'])[0],2)*100
print(f"The correlation between precip and accidents for zip code 30309 is {rain_corr_30309}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between precip and accidents for zip code 30309 is 6.0%
# slope: 0.208998  intercept: 2.246279
# R-Squared: 0.003345

# %%
# rain 30340
(slope, intercept, rvalue, pvalue, stderr) = linregress(precip30340['Precipitation'], precip30340['Accident_ct'])
regress_values = slope * precip30340['Precipitation'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(precip30340['Precipitation'], precip30340['Accident_ct'])
plt.plot(precip30340['Precipitation'], regress_values, color = 'red')
plt.annotate(line_eq,(1.5,15),fontsize=15,color="red")
plt.xlabel("Precip")
plt.ylabel("Accidents")
plt.title("Accident Data 30340")
rain_corr_30340=round(st.pearsonr(precip30340['Precipitation'], precip30340['Accident_ct'])[0],2)*100
print(f"The correlation between precip and accidents for zip code 30340 is {rain_corr_30340}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
plt.savefig("rain_30340")
# Out:
# The correlation between precip and accidents for zip code 30340 is 26.0%
# slope: 0.988305  intercept: 1.118484
# R-Squared: 0.065671

# %%
# rain 30308
(slope, intercept, rvalue, pvalue, stderr) = linregress(precip30308['Precipitation'], precip30308['Accident_ct'])
regress_values = slope * precip30308['Precipitation'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(precip30308['Precipitation'], precip30308['Accident_ct'])
plt.plot(precip30308['Precipitation'], regress_values, color = 'red')
plt.annotate(line_eq,(1.5,7),fontsize=15,color="red")
plt.xlabel("Precip")
plt.ylabel("Accidents")
plt.title("Accident Data 30308")
rain_corr_30308=round(st.pearsonr(precip30308['Precipitation'], precip30308['Accident_ct'])[0],2)*100
print(f"The correlation between precip and accidents for zip code 30308 is {rain_corr_30308}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between precip and accidents for zip code 30308 is -2.0%
# slope: -0.071644  intercept: 1.928229
# R-Squared: 0.000475

# %%
# rain 30324
(slope, intercept, rvalue, pvalue, stderr) = linregress(precip30324['Precipitation'], precip30324['Accident_ct'])
regress_values = slope * precip30324['Precipitation'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(precip30324['Precipitation'], precip30324['Accident_ct'])
plt.plot(precip30324['Precipitation'], regress_values, color = 'red')
plt.annotate(line_eq,(1.5,6),fontsize=15,color="red")
plt.xlabel("Precip")
plt.ylabel("Accidents")
plt.title("Accident Data 30324")
rain_corr_30324=round(st.pearsonr(precip30324['Precipitation'], precip30324['Accident_ct'])[0],2)*100
print(f"The correlation between precip and accidents for zip code 30324 is {rain_corr_30324}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between precip and accidents for zip code 30324 is 0.0%
# slope: 0.009888  intercept: 1.640286
# R-Squared: 0.000014

# %%
# rain 30342
(slope, intercept, rvalue, pvalue, stderr) = linregress(precip30342['Precipitation'], precip30342['Accident_ct'])
regress_values = slope * precip30342['Precipitation'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(precip30342['Precipitation'], precip30342['Accident_ct'])
plt.plot(precip30342['Precipitation'], regress_values, color = 'red')
plt.annotate(line_eq,(1.5,7),fontsize=15,color="red")
plt.xlabel("Precip")
plt.ylabel("Accidents")
plt.title("Accident Data 30342")
rain_corr_30342=round(st.pearsonr(precip30342['Precipitation'], precip30342['Accident_ct'])[0],2)*100
print(f"The correlation between precip and accidents for zip code 30342 is {rain_corr_30342}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between precip and accidents for zip code 30342 is 8.0%
# slope: 0.198193  intercept: 1.128483
# R-Squared: 0.006622

# %%
# rain 30318
(slope, intercept, rvalue, pvalue, stderr) = linregress(precip30318['Precipitation'], precip30318['Accident_ct'])
regress_values = slope * precip30318['Precipitation'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(precip30318['Precipitation'], precip30318['Accident_ct'])
plt.plot(precip30318['Precipitation'], regress_values, color = 'red')
plt.annotate(line_eq,(1.5,6),fontsize=15,color="red")
plt.xlabel("Precip")
plt.ylabel("Accidents")
plt.title("Accident Data 30318")
rain_corr_30318=round(st.pearsonr(precip30318['Precipitation'], precip30318['Accident_ct'])[0],2)*100
print(f"The correlation between precip and accidents for zip code 30318 is {rain_corr_30318}%")
print ("slope: %f  intercept: %f" % (slope, intercept))
print("R-Squared: %f" % rvalue**2)
# Out:
# The correlation between precip and accidents for zip code 30318 is 6.0%
# slope: 0.166247  intercept: 1.405027
# R-Squared: 0.004161
